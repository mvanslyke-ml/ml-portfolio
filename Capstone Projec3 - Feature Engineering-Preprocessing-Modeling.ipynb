# %% [markdown]
# ***
# ### CAPSTONE PROJECT 3: FEATURE ENGINEERING/PRE-PROCESSING/MODELING ###
# ***
# - Review the PCA's generated from the DATA CLEANING/EDA
# - Determine how many PCAs required
# - Deterrmine if only most important Eigen values from PCAs would be sufficient to model.
# - separate table into X and y sets.
# - create Train and test data sets.
# - setup ARIMA models
# - setup LSTM Model
# - setup SARIMAX model.
# - train models
# - evaluate models.
# - decide which model serves best and why.

# %%
# Basic Data Science Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy

# Models to test and scalar
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
#   LSTM
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# SARIMAX
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima

# Model Metrics
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ***
# ##### FEATURE ENGINEERING
# ***
# Determine Number of PCA's Required or if only important Eigen values from PCAs would be sufficient for our model

# %%
# Linux
# bitcoin_df = pd.read_csv('./Data/bitcoin_df_cleaned')
# most_important_features = pd.read_csv('./Data/most_important_features')

# Windows
bitcoin_df = pd.read_csv(r'C:\Users\micha\OneDrive\Documents\GitHub\SpringBoardDataScience\Capstone_Project_3\Data\bitcoin_df_cleaned')
most_important_features = pd.read_csv(r'C:\Users\micha\OneDrive\Documents\GitHub\SpringBoardDataScience\Capstone_Project_3\Data\most_important_features')

# %%
bitcoin_df.head()
# Out:
#          date  USD Exchange Trade Volume  Total Transaction Fees USD  \
# 0  2009-01-03                        0.0                         0.0
# 1  2009-01-04                        0.0                         0.0
# 2  2009-01-05                        0.0                         0.0
# 3  2009-01-06                        0.0                         0.0
# 4  2009-01-07                        0.0                         0.0
#
#    Total Transaction Fees  Total Output Volume  Total Bitcoins  \
# 0                     0.0                  0.0            50.0
# 1                     0.0                  0.0            50.0
# 2                     0.0                  0.0            50.0
# 3                     0.0                  0.0            50.0
# 4                     0.0                  0.0            50.0
#
#    Transaction Excluding Popular Addresses  Number of Transactions per Block  \
# 0                                      0.0                               1.0
# 1                                      0.0                               1.0
# 2                                      0.0                               1.0
# 3                                      0.0                               1.0
# 4                                      0.0                               1.0
#
#    Total Number of Transactions  Number of Transactions  ...      PCA3  \
# 0                           1.0                     0.0  ...  0.569005
# 1                           1.0                     0.0  ...  0.569005
# 2                           1.0                     0.0  ...  0.569005
# 3                           1.0                     0.0  ...  0.569005
# 4                           1.0                     0.0  ...  0.569005
#
#        PCA4      PCA5      PCA6      PCA7     PCA8     PCA9     PCA10  \
# 0 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 1 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 2 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 3 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 4 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
#
#       PCA11     PCA12
# 0  0.364128 -0.185659
# 1  0.364128 -0.185659
# 2  0.364128 -0.185659
# 3  0.364128 -0.185659
# 4  0.364128 -0.185659
#
# [5 rows x 38 columns]

# %%
bitcoin_df.columns
# Out:
# Index(['date', 'USD Exchange Trade Volume', 'Total Transaction Fees USD',
#        'Total Transaction Fees', 'Total Output Volume', 'Total Bitcoins',
#        'Transaction Excluding Popular Addresses',
#        'Number of Transactions per Block', 'Total Number of Transactions',
#        'Number of Transactions', 'Number of Unique Addresses Used',
#        'My Wallet Transaction Volume', 'My Wallet Number of Users',
#        'Number of Transactions per Day', 'Market Capitalization',
#        'Market Price', 'Miners Revenue', 'Hash Rate',
#        'Estimated Transaction Volume USD', 'Estimated Transaction Volume',
#        'Difficulty', 'Cost Percent of Transaction Volume',
#        'Cost per Transaction', 'API Blockchain Size', 'Average Block Size',
#        'Median Transaction Confirmation Time', 'PCA1', 'PCA2', 'PCA3', 'PCA4',
#        'PCA5', 'PCA6', 'PCA7', 'PCA8', 'PCA9', 'PCA10', 'PCA11', 'PCA12'],
#       dtype='object')

# %%
print(most_important_features['Feature Name'])
# Out:
# 0                             Difficulty
# 1                  Market Capitalization
# 2       Estimated Transaction Volume USD
# 3              USD Exchange Trade Volume
# 4           Total Number of Transactions
# 5                              Hash Rate
# 6              My Wallet Number of Users
# 7                         Miners Revenue
# 8                         Total Bitcoins
# 9                    Total Output Volume
# 10            Total Transaction Fees USD
# 11    Cost Percent of Transaction Volume
# Name: Feature Name, dtype: object

# %% [markdown]
# Since we're dealing with Cybercurrency rather than stocks, we should resample this data taking the final value per month and also start performing percentchanges per column and autocorrelation functions as we curate a final feature set with which to model.

# %%
bitcoin_df.head()
# Out:
#          date  USD Exchange Trade Volume  Total Transaction Fees USD  \
# 0  2009-01-03                        0.0                         0.0
# 1  2009-01-04                        0.0                         0.0
# 2  2009-01-05                        0.0                         0.0
# 3  2009-01-06                        0.0                         0.0
# 4  2009-01-07                        0.0                         0.0
#
#    Total Transaction Fees  Total Output Volume  Total Bitcoins  \
# 0                     0.0                  0.0            50.0
# 1                     0.0                  0.0            50.0
# 2                     0.0                  0.0            50.0
# 3                     0.0                  0.0            50.0
# 4                     0.0                  0.0            50.0
#
#    Transaction Excluding Popular Addresses  Number of Transactions per Block  \
# 0                                      0.0                               1.0
# 1                                      0.0                               1.0
# 2                                      0.0                               1.0
# 3                                      0.0                               1.0
# 4                                      0.0                               1.0
#
#    Total Number of Transactions  Number of Transactions  ...      PCA3  \
# 0                           1.0                     0.0  ...  0.569005
# 1                           1.0                     0.0  ...  0.569005
# 2                           1.0                     0.0  ...  0.569005
# 3                           1.0                     0.0  ...  0.569005
# 4                           1.0                     0.0  ...  0.569005
#
#        PCA4      PCA5      PCA6      PCA7     PCA8     PCA9     PCA10  \
# 0 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 1 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 2 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 3 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
# 4 -0.568879 -0.054665 -0.091244  0.242654  0.28525 -0.60444 -0.121818
#
#       PCA11     PCA12
# 0  0.364128 -0.185659
# 1  0.364128 -0.185659
# 2  0.364128 -0.185659
# 3  0.364128 -0.185659
# 4  0.364128 -0.185659
#
# [5 rows x 38 columns]

# %%
# Linux Machine
# bitcoin_df['date'] = pd.to_datetime(bitcoin_df['date'])
# bitcoin_df.set_index('date', inplace=True)
# monthly_bitcoin_df = bitcoin_df.resample(rule='ME').last()

# Windows Machine
bitcoin_df['date'] = pd.to_datetime(bitcoin_df['date'])
bitcoin_df.set_index('date', inplace=True)
monthly_bitcoin_df = bitcoin_df.resample(rule='M').last()

# %%
monthly_bitcoin_df.head()
# Out:
#             USD Exchange Trade Volume  Total Transaction Fees USD  \
# date
# 2009-01-31                        0.0                         0.0
# 2009-02-28                        0.0                         0.0
# 2009-03-31                        0.0                         0.0
# 2009-04-30                        0.0                         0.0
# 2009-05-31                        0.0                         0.0
#
#             Total Transaction Fees  Total Output Volume  Total Bitcoins  \
# date
# 2009-01-31                     0.0               6900.0        131350.0
# 2009-02-28                     0.0               5650.0        300350.0
# 2009-03-31                     0.0               7100.0        473700.0
# 2009-04-30                     0.0               6550.0        646200.0
# 2009-05-31                     0.0               3700.0        814050.0
#
#             Transaction Excluding Popular Addresses  \
# date
# 2009-01-31                                    118.0
# 2009-02-28                                    107.0
# 2009-03-31                                    111.0
# 2009-04-30                                    131.0
# 2009-05-31                                     74.0
#
#             Number of Transactions per Block  Total Number of Transactions  \
# date
# 2009-01-31                            1.0000                        2660.0
# 2009-02-28                            1.0101                        5894.0
# 2009-03-31                            1.0000                        9564.0
# 2009-04-30                            1.0000                       13031.0
# 2009-05-31                            1.0000                       16407.0
#
#             Number of Transactions  Number of Unique Addresses Used  ...  \
# date                                                                 ...
# 2009-01-31                   118.0                            118.0  ...
# 2009-02-28                   100.0                            107.0  ...
# 2009-03-31                   107.0                            107.0  ...
# 2009-04-30                   123.0                            123.0  ...
# 2009-05-31                    74.0                             97.0  ...
#
#                 PCA3      PCA4       PCA5       PCA6      PCA7      PCA8  \
# date
# 2009-01-31  0.565030 -0.563939  -0.054191  -0.089885  0.239737  0.282748
# 2009-02-28  0.560211 -0.563640  -0.051130  -0.094561  0.240379  0.281682
# 2009-03-31  0.555188 -0.561716  -0.052657  -0.099386  0.240415  0.280493
# 2009-04-30  0.550199 -0.559929  -0.051917  -0.102584  0.239699  0.277679
# 2009-05-31  1.580360 -3.325415  61.876607  19.669443 -3.406495 -0.765949
#
#                 PCA9     PCA10     PCA11     PCA12
# date
# 2009-01-31 -0.602849 -0.120739  0.357469 -0.182035
# 2009-02-28 -0.597189 -0.119256  0.350008 -0.177898
# 2009-03-31 -0.592182 -0.117801  0.342172 -0.173529
# 2009-04-30 -0.587518 -0.116157  0.334166 -0.169215
# 2009-05-31  1.014664  0.145786 -0.260525  0.111816
#
# [5 rows x 37 columns]

# %%
most_important_features_list = list(most_important_features['Feature Name'].unique())

# %%
def feature_correlation(df, feature_list):
    pct_change_df = pd.DataFrame()
    for feature in feature_list:
       pct_change_df[f'{feature}_RET']  = df[feature].pct_change()
       
    corr = pct_change_df.corr()
    sns.heatmap(corr)

# %%
_ = feature_correlation(monthly_bitcoin_df, most_important_features_list)

# %%
PCA_list = ['PCA1', 'PCA2', 'PCA3', 'PCA4', 'PCA5', 'PCA6', 'PCA7', 'PCA8', 'PCA9', 'PCA10', 'PCA11', 'PCA12']
_ = feature_correlation(monthly_bitcoin_df, PCA_list)

# %% [markdown]
# These heatmaps pretty clearly say that for our feature set, we should use our curated PCAs rather then the primary Eigen values particularly since their degree of correlation is almost all zero which means little to no correlation between these PC vectors.  which for a multivariate time series analysis is exactly what we want.  NO CONFOUNDING VARIABLES!

# %%
monthly_pca_bitcoin_df = monthly_bitcoin_df[PCA_list]
monthly_pca_bitcoin_df['Market Price'] = monthly_bitcoin_df.loc[:,'Market Price']
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\203295870.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df['Market Price'] = monthly_bitcoin_df.loc[:,'Market Price']

# %%
monthly_pca_bitcoin_df.head()
# Out:
#                 PCA1      PCA2      PCA3      PCA4       PCA5       PCA6  \
# date
# 2009-01-31 -4.303479 -1.979341  0.565030 -0.563939  -0.054191  -0.089885
# 2009-02-28 -4.297004 -1.974127  0.560211 -0.563640  -0.051130  -0.094561
# 2009-03-31 -4.290207 -1.967827  0.555188 -0.561716  -0.052657  -0.099386
# 2009-04-30 -4.283464 -1.961293  0.550199 -0.559929  -0.051917  -0.102584
# 2009-05-31 -4.717936 -3.377790  1.580360 -3.325415  61.876607  19.669443
#
#                 PCA7      PCA8      PCA9     PCA10     PCA11     PCA12  \
# date
# 2009-01-31  0.239737  0.282748 -0.602849 -0.120739  0.357469 -0.182035
# 2009-02-28  0.240379  0.281682 -0.597189 -0.119256  0.350008 -0.177898
# 2009-03-31  0.240415  0.280493 -0.592182 -0.117801  0.342172 -0.173529
# 2009-04-30  0.239699  0.277679 -0.587518 -0.116157  0.334166 -0.169215
# 2009-05-31 -3.406495 -0.765949  1.014664  0.145786 -0.260525  0.111816
#
#             Market Price
# date
# 2009-01-31           0.0
# 2009-02-28           0.0
# 2009-03-31           0.0
# 2009-04-30           0.0
# 2009-05-31           0.0

# %%
pct_change_df = pd.DataFrame()
for feature in PCA_list:
    pct_change_df[f'{feature}_RET']  = monthly_bitcoin_df[feature].pct_change()

# %%
for col in pct_change_df.columns:
    print(f'Autocorrelation for {col} is: {pct_change_df[col]}')
# Out:
# Autocorrelation for PCA1_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.001505
# 2009-03-31   -0.001582
# 2009-04-30   -0.001572
# 2009-05-31    0.101430
#                 ...
# 2024-01-31   -0.182696
# 2024-02-29    0.250034
# 2024-03-31   -0.156358
# 2024-04-30    0.016547
# 2024-05-31    0.046690
# Freq: M, Name: PCA1_RET, Length: 185, dtype: float64
# Autocorrelation for PCA2_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.002634
# 2009-03-31   -0.003192
# 2009-04-30   -0.003320
# 2009-05-31    0.722226
#                 ...
# 2024-01-31    2.043564
# 2024-02-29    0.521250
# 2024-03-31    0.346441
# 2024-04-30   -0.258748
# 2024-05-31    0.036809
# Freq: M, Name: PCA2_RET, Length: 185, dtype: float64
# Autocorrelation for PCA3_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.008529
# 2009-03-31   -0.008966
# 2009-04-30   -0.008986
# 2009-05-31    1.872341
#                 ...
# 2024-01-31   -1.125360
# 2024-02-29   -9.346899
# 2024-03-31   -1.069267
# 2024-04-30    3.164233
# 2024-05-31    0.415148
# Freq: M, Name: PCA3_RET, Length: 185, dtype: float64
# Autocorrelation for PCA4_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.000530
# 2009-03-31   -0.003414
# 2009-04-30   -0.003181
# 2009-05-31    4.939000
#                 ...
# 2024-01-31   -1.045779
# 2024-02-29    2.600779
# 2024-03-31   -0.487918
# 2024-04-30   -3.129705
# 2024-05-31    0.001188
# Freq: M, Name: PCA4_RET, Length: 185, dtype: float64
# Autocorrelation for PCA5_RET is: date
# 2009-01-31            NaN
# 2009-02-28      -0.056491
# 2009-03-31       0.029869
# 2009-04-30      -0.014066
# 2009-05-31   -1192.848241
#                  ...
# 2024-01-31      -0.512448
# 2024-02-29      -0.117230
# 2024-03-31      -0.257626
# 2024-04-30       0.994713
# 2024-05-31      -0.117290
# Freq: M, Name: PCA5_RET, Length: 185, dtype: float64
# Autocorrelation for PCA6_RET is: date
# 2009-01-31           NaN
# 2009-02-28      0.052023
# 2009-03-31      0.051026
# 2009-04-30      0.032182
# 2009-05-31   -192.739587
#                  ...
# 2024-01-31     -0.452522
# 2024-02-29     -0.177404
# 2024-03-31     -0.293385
# 2024-04-30      1.158987
# 2024-05-31     -0.111113
# Freq: M, Name: PCA6_RET, Length: 185, dtype: float64
# Autocorrelation for PCA7_RET is: date
# 2009-01-31          NaN
# 2009-02-28     0.002676
# 2009-03-31     0.000151
# 2009-04-30    -0.002980
# 2009-05-31   -15.211567
#                 ...
# 2024-01-31     7.985815
# 2024-02-29    -0.475669
# 2024-03-31    -3.923142
# 2024-04-30    -0.927685
# 2024-05-31     2.411028
# Freq: M, Name: PCA7_RET, Length: 185, dtype: float64
# Autocorrelation for PCA8_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.003771
# 2009-03-31   -0.004222
# 2009-04-30   -0.010033
# 2009-05-31   -3.758403
#                 ...
# 2024-01-31   -1.436625
# 2024-02-29    0.708737
# 2024-03-31   -0.605795
# 2024-04-30   -0.868365
# 2024-05-31    1.258960
# Freq: M, Name: PCA8_RET, Length: 185, dtype: float64
# Autocorrelation for PCA9_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.009388
# 2009-03-31   -0.008384
# 2009-04-30   -0.007876
# 2009-05-31   -2.727036
#                 ...
# 2024-01-31   -1.254213
# 2024-02-29    1.002347
# 2024-03-31    2.527092
# 2024-04-30   -0.634475
# 2024-05-31   -0.035792
# Freq: M, Name: PCA9_RET, Length: 185, dtype: float64
# Autocorrelation for PCA10_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.012279
# 2009-03-31   -0.012202
# 2009-04-30   -0.013960
# 2009-05-31   -2.255081
#                 ...
# 2024-01-31   -1.316454
# 2024-02-29    2.370604
# 2024-03-31   -1.267033
# 2024-04-30   -2.420567
# 2024-05-31    0.197122
# Freq: M, Name: PCA10_RET, Length: 185, dtype: float64
# Autocorrelation for PCA11_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.020871
# 2009-03-31   -0.022389
# 2009-04-30   -0.023397
# 2009-05-31   -1.779628
#                 ...
# 2024-01-31    9.120322
# 2024-02-29    0.077299
# 2024-03-31   -1.332190
# 2024-04-30   -2.891805
# 2024-05-31   -0.078497
# Freq: M, Name: PCA11_RET, Length: 185, dtype: float64
# Autocorrelation for PCA12_RET is: date
# 2009-01-31         NaN
# 2009-02-28   -0.022729
# 2009-03-31   -0.024560
# 2009-04-30   -0.024859
# 2009-05-31   -1.660793
#                 ...
# 2024-01-31   -1.950507
# 2024-02-29   -0.542630
# 2024-03-31    0.074597
# 2024-04-30   -0.056619
# 2024-05-31   -0.087476
# Freq: M, Name: PCA12_RET, Length: 185, dtype: float64

# %%
for col in monthly_pca_bitcoin_df.columns:
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))
    plot_acf(monthly_pca_bitcoin_df[col], lags=20, alpha=0.05, ax=ax1)
    plot_pacf(monthly_pca_bitcoin_df[col], lags=20, alpha=0.05, ax=ax2)
    plt.suptitle(col)

# %%
for col in monthly_pca_bitcoin_df.columns:
    results = adfuller(monthly_pca_bitcoin_df[col])
    print(f'{col}: {results[1]}')
# Out:
# PCA1: 0.99544513096988
# PCA2: 0.6542293613635672
# PCA3: 0.0009402391804554215
# PCA4: 0.0014578877531899212
# PCA5: 1.3038107021306502e-07
# PCA6: 0.0010083547578129467
# PCA7: 1.9894343520709487e-07
# PCA8: 2.330874518102699e-21
# PCA9: 0.03418147489354851
# PCA10: 0.025462673002544945
# PCA11: 0.001230417822890735
# PCA12: 0.00012315417013806167
# Market Price: 0.9497434815733111

# %% [markdown]
# As per the adfuller test: PCA's _1, 2, 6_ and _Market Price_ are non-stationary whilst the rest are comfortably below our p-values indicating their usefulness for modeling.

# %%
for feature in monthly_pca_bitcoin_df.columns:
    sns.lineplot(monthly_pca_bitcoin_df[feature])
    plt.title(feature)
    plt.xlabel('date')
    plt.ylabel('values')
    plt.show()
    plt.close()

# %%
fig, ax = plt.subplots(ncols=2, nrows=4, figsize=(20,20))

ax[0][0].plot(monthly_pca_bitcoin_df['PCA1'])
ax[0][1].plot(np.log(abs(monthly_pca_bitcoin_df['PCA1'])).diff(3))

ax[1][0].plot(monthly_pca_bitcoin_df['PCA2'])
ax[1][1].plot(monthly_pca_bitcoin_df['PCA2'].diff())

ax[2][0].plot(monthly_pca_bitcoin_df['PCA6'])
ax[2][1].plot(monthly_pca_bitcoin_df['PCA6'].diff())

ax[3][0].plot(monthly_pca_bitcoin_df['Market Price'])
ax[3][1].plot(np.log(abs(monthly_pca_bitcoin_df['Market Price'])).diff())
# Out:
# c:\Users\micha\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
np.log(abs(monthly_pca_bitcoin_df['PCA1'])).diff()
# Out:
# date
# 2009-01-31         NaN
# 2009-02-28   -0.001506
# 2009-03-31   -0.001583
# 2009-04-30   -0.001573
# 2009-05-31    0.096609
#                 ...
# 2024-01-31   -0.201744
# 2024-02-29    0.223171
# 2024-03-31   -0.170027
# 2024-04-30    0.016411
# 2024-05-31    0.045632
# Freq: M, Name: PCA1, Length: 185, dtype: float64

# %% [markdown]
# That should take care of our Transformations necessary for our Models so let's save these transforms into our *monthly_pca_bitcoin_df* and proceed to our preprocessing phase.

# %%
for pc in ['PCA1', 'PCA2', 'PCA6', 'Market Price']:
    if pc == 'PCA1':
        monthly_pca_bitcoin_df[f'{pc}_stationary'] = np.log(abs(monthly_pca_bitcoin_df['PCA1'])).diff(3)
    elif pc == 'Market Price':
       monthly_pca_bitcoin_df[f'{pc}_stationary'] = np.log(abs(monthly_pca_bitcoin_df['Market Price'])).diff()
    else:
        monthly_pca_bitcoin_df[f'{pc}_stationary'] = monthly_pca_bitcoin_df[pc].diff()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\37240690.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df[f'{pc}_stationary'] = np.log(abs(monthly_pca_bitcoin_df['PCA1'])).diff(3)
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\37240690.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df[f'{pc}_stationary'] = monthly_pca_bitcoin_df[pc].diff()
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\37240690.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df[f'{pc}_stationary'] = monthly_pca_bitcoin_df[pc].diff()
# c:\Users\micha\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\37240690.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df[f'{pc}_stationary'] = np.log(abs(monthly_pca_bitcoin_df['Market Price'])).diff()

# %%
monthly_pca_bitcoin_df.dropna(inplace=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\1539485645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df.dropna(inplace=True)

# %%
monthly_pca_bitcoin_df.drop(index='2010-08-31', inplace=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_98944\96756979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_pca_bitcoin_df.drop(index='2010-08-31', inplace=True)

# %%
for col in monthly_pca_bitcoin_df.columns:
    if col == 'PCA1' or col == 'PCA2' or col == 'PCA6' or col == 'Market Price':
        continue
    else:
        results = adfuller(monthly_pca_bitcoin_df[col])
        print(f'{col}: {results[1]}')
# Out:
# PCA3: 0.0015679565075756563
# PCA4: 0.001260847275973367
# PCA5: 0.8274713608287655
# PCA7: 6.612713396672285e-06
# PCA8: 7.2963370334111006e-06
# PCA9: 0.02184508586620146
# PCA10: 0.007307720670936495
# PCA11: 0.002658990737473684
# PCA12: 0.00034308953222023705
# PCA1_stationary: 1.4343614077033744e-17
# PCA2_stationary: 1.86000012341913e-25
# PCA6_stationary: 2.11056197691341e-15
# Market Price_stationary: 2.2570470620970784e-06

# %% [markdown]
# All of our features are now sufficiently stationary for the Analysis.

# %% [markdown]
# ***
# ##### Pre-Processing
# ***
# - Separate into _X_ and _y_ and create _train_, _test_ and/or _validate_ data sets

# %%
X_prime = monthly_pca_bitcoin_df[['PCA1_stationary', 'PCA2_stationary', 'PCA3', 'PCA4',
                                  'PCA5', 'PCA6_stationary', 'PCA7', 'PCA8', 'PCA9',
                                  'PCA10', 'PCA11', 'PCA12', 'Market Price_stationary']].rename(columns={'PCA1_stationary': 'PCA1',
                                                                                                         'PCA2_stationary': 'PCA2', 
                                                                                                         'PCA6_stationary': 'PCA6',
                                                                                                         'Market Price_stationary': 'Market Price'})

# %%
X_prime.head()
# Out:
#                 PCA1      PCA2      PCA3      PCA4      PCA5      PCA6  \
# date
# 2010-09-30 -0.010336  0.010967  0.454551 -0.442915 -0.062848 -0.010012
# 2010-10-31 -0.011741 -0.002829  0.463001 -0.421634 -0.054172 -0.028095
# 2010-11-30 -0.010639  0.051903  0.450317 -0.378658 -0.079583  0.076035
# 2010-12-31 -0.011938 -0.047017  0.442663 -0.445379 -0.039219 -0.124594
# 2011-01-31 -0.007806  0.066603  0.431579 -0.381060 -0.068381  0.092782
#
#                 PCA7      PCA8      PCA9     PCA10     PCA11     PCA12  \
# date
# 2010-09-30  0.165154  0.161381 -0.533707 -0.075476  0.144298 -0.077008
# 2010-10-31  0.171544  0.151653 -0.517539 -0.059395  0.101462 -0.075337
# 2010-11-30  0.115946  0.074011 -0.546958 -0.053924  0.081190 -0.063967
# 2010-12-31  0.196844  0.184849 -0.484988 -0.059855  0.088238 -0.062100
# 2011-01-31  0.133499  0.131493 -0.524707 -0.060113  0.069921 -0.052373
#
#             Market Price
# date
# 2010-09-30     -0.045713
# 2010-10-31      1.119890
# 2010-11-30      0.387766
# 2010-12-31      0.068993
# 2011-01-31      1.152680

# %% [markdown]
# - ##### ARIMA MODELS #####
# ***

# %%
# Univariate Model data
X_univar = X_prime['Market Price']

X_train = X_univar[:int(len(X_univar) * 0.8)]
X_test = X_univar[int(len(X_univar) * 0.8):]

# %%
def ARIMA_model_selector(X, pval=3, dval=3, qval=3):
    '''Takes a univarate dataset and p, d, q parameters for an ARIMA model
    and fits, measures, and visualizes the resultant data. selects the best scores
    from both the AIC and BIC metrics and takes their full diagnostic for suitability
    returns metrics_df for further diagnostics if the lowest AIC/BIC scores are not suitable'''
    # Test Models
    model_metrics = {'AIC': {}, 'BIC': {}, 'pdq': {}}
    best_models = {'AIC': None, 'BIC': None}

    for d in range(dval):
        for p in range(pval):
            for q in range(qval):
                try:
                    model = ARIMA(X, order=(p,d,q))
                    results = model.fit()

                    model_metrics['AIC'][f'ARIMA({p},{d},{q})'] = results.aic
                    model_metrics['BIC'][f'ARIMA({p},{d},{q})'] = results.bic
                    model_metrics['pdq'][f'ARIMA({p},{d},{q})'] = (p,d,q)

                    if best_models['AIC'] == None and best_models['BIC'] == None:
                        best_models['AIC'] = [model, results]
                        best_models['BIC'] = [model, results]

                    elif best_models['AIC'][1].aic > results.aic and best_models['BIC'][1].bic > results.bic:
                        best_models['AIC'] = [model, results]
                        best_models['BIC'] = [model, results]
                        print('\nUpdated ARIMA aic and bic selection:')
                        print(f'order: ({p}, {d}, {q}) aic-score: {results.aic} bic-score:{results.bic}')

                    elif best_models['AIC'][1].aic > results.aic and best_models['BIC'][1].bic < results.bic:
                        best_models['AIC'] = [model, results]
                        print('\nUpdated ARIMA aic selection:')
                        print(f'order: ({p}, {d}, {q}) score: {results.aic}')

                    elif best_models['BIC'][1].bic > results.bic and best_models['AIC'][1].aic < results.aic:
                        best_models['BIC'] = [model, results]
                        print('\nUpdated ARIMA bic selection:')
                        print(f'order: ({p}, {d}, {q}) score: {results.bic}')

                    else:
                        print(p, d, q, results.aic, results.bic)

                except:
                    print(p, d, q, None, None)
    # Visualize AIC vs BIC scores            
    metrics_df = pd.DataFrame(model_metrics)

    plt.plot(metrics_df['AIC'], label='AIC')
    plt.plot(metrics_df['BIC'], label='BIC')
    plt.legend()
    plt.title('Model Fit Metrics')
    plt.xlabel('Models')
    plt.xticks(rotation=90)
    plt.ylabel('Scores')
    plt.show()

    # Select lowest scores from AIC and BIC and then pull their Summary and visualize their full metrics.
    for key in best_models:
        best_models[key][1].plot_diagnostics()
        print(best_models[key][1].summary())
    
    return metrics_df, best_models

# %%
metrics_df, best_models = ARIMA_model_selector(X_univar)
# Out:
# Updated ARIMA aic and bic selection:
# order: (0, 0, 1) aic-score: 85.87607075312972 bic-score:95.19390717483147
# 0 0 2 87.87595267219592 100.29973456779824
# 1 0 0 85.9115289768137 95.22936539851544
# 1 0 1 87.87530053371616 100.29908242931847
# 1 0 2 89.64934920539035 105.17907657489326
# 2 0 0 87.90473314000114 100.32851503560346
# 2 0 1 89.5119451425297 105.04167251203259
# c:\Users\micha\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\micha\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# 2 0 2 91.15451618638495 109.79018902978844
# 0 1 0 161.61264148555048 164.71250791337468
# 0 1 1 95.39394748872918 101.59368034437757
# 0 1 2 90.00702244812965 99.30662173160223
# 1 1 0 137.32376748476756 143.52350034041595
# 1 1 1 90.1745241841757 99.4741234676483
# 1 1 2 91.95520273142144 104.35466844271824
# 2 1 0 120.0523440529372 129.3519433364098
# 2 1 1 92.14138412603135 104.54084983732815
# 2 1 2 93.68723354616722 109.18656568528822
# 0 2 0 323.299481674168 326.3932318749748
# 0 2 1 168.73873922764915 174.92623962926268
# 0 2 2 107.50134956674025 116.78260016916053
# 1 2 0 258.95415434702437 265.1416547486379
# 1 2 1 145.26271196618507 154.54396256860537
# c:\Users\micha\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\micha\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\micha\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 2 2 101.40769275945881 113.78269356268586
# 2 2 0 205.17754890080624 214.45879950322654
# 2 2 1 128.66820055879026 141.04320136201733
# 2 2 2 103.47144859551244 118.94019959954625
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Market Price   No. Observations:                  165
# Model:                 ARIMA(0, 0, 1)   Log Likelihood                 -39.938
# Date:                Thu, 30 May 2024   AIC                             85.876
# Time:                        18:09:08   BIC                             95.194
# Sample:                    09-30-2010   HQIC                            89.659
#                          - 05-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0836      0.038      2.178      0.029       0.008       0.159
# ma.L1          0.2394      0.067      3.567      0.000       0.108       0.371
# sigma2         0.0950      0.006     15.053      0.000       0.083       0.107
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               385.50
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                             1.77
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Market Price   No. Observations:                  165
# Model:                 ARIMA(0, 0, 1)   Log Likelihood                 -39.938
# Date:                Thu, 30 May 2024   AIC                             85.876
# Time:                        18:09:08   BIC                             95.194
# Sample:                    09-30-2010   HQIC                            89.659
#                          - 05-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0836      0.038      2.178      0.029       0.008       0.159
# ma.L1          0.2394      0.067      3.567      0.000       0.108       0.371
# sigma2         0.0950      0.006     15.053      0.000       0.083       0.107
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               385.50
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                             1.77
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# These results concur from both the AIC and BIC scores that an ARIMA(0,0,1) or MA model would work best for this univariate series. the summary in the Prob(Q) confirms that residuals are definitely uncorrelated, our theoretical quantiles are reasonabley close to the linear regression and almost all points fall within the confidence area of the correlogram.  So without very little doubt as to the this being the best univariate ARIMA (MA) Model we could do.

# %%
def convert_statpred_to_origpred(stationary_predictions, original_data):
  """Converts stationary predictions to original predictions.

  Args:
    stationary_predictions: A NumPy array of stationary predictions.
    original_data: A NumPy array of original data.

  Returns:
    A NumPy array of original predictions.
  """

  # Calculate the cumulative sum of the stationary predictions.
  cumulative_sum = np.cumsum(stationary_predictions)

  # Add the first value of the original data to the cumulative sum.
  try:
    cumulative_sum += original_data.iloc[0]
  except:
    cumulative_sum += original_data[0]

  # Calculate the original predictions by taking the exponential of the cumulative sum.
  original_predictions = np.exp(cumulative_sum)

  return original_predictions

# %%
ARIMA_model, ARIMA_results = best_models['AIC']

# %%
ARIMA_predictions = ARIMA_results.get_prediction(start=0)
ARIMA_predictions_orig = convert_statpred_to_origpred(ARIMA_predictions.predicted_mean[-len(X_test):], X_test)

# %%
ARIMA_predictionsci = ARIMA_predictions.conf_int()

# %%
lower_ci = ARIMA_predictionsci['lower Market Price']
upper_ci = ARIMA_predictionsci['upper Market Price']

# %%
rmse = np.sqrt(mean_squared_error(X_test, ARIMA_predictions.predicted_mean[-len(X_test):]))
print('RMSE:', rmse)
# Out:
# RMSE: 0.19732524897699033

# %%
ARIMA_predictions_orig
# Out:
# date
# 2021-09-30    0.960784
# 2021-10-31    0.993141
# 2021-11-30    1.177944
# 2021-12-31    1.210360
# 2022-01-31    1.244951
# 2022-02-28    1.276229
# 2022-03-31    1.377478
# 2022-04-30    1.550695
# 2022-05-31    1.562825
# 2022-06-30    1.618114
# 2022-07-31    1.563951
# 2022-08-31    1.782638
# 2022-09-30    1.800017
# 2022-10-31    1.947904
# 2022-11-30    2.103809
# 2022-12-31    2.126575
# 2023-01-31    2.311732
# 2023-02-28    2.659171
# 2023-03-31    2.815020
# 2023-04-30    3.149450
# 2023-05-31    3.367338
# 2023-06-30    3.556546
# 2023-07-31    3.903848
# 2023-08-31    4.111882
# 2023-09-30    4.342192
# 2023-10-31    4.644013
# 2023-11-30    5.272804
# 2023-12-31    5.686478
# 2024-01-31    6.229475
# 2024-02-29    6.656626
# 2024-03-31    7.792633
# 2024-04-30    8.373194
# 2024-05-31    8.763441
# Freq: M, Name: predicted_mean, dtype: float64

# %%
_, (ax1,ax2,ax3) = plt.subplots(nrows=3, figsize=(15,15))
ax1.plot(X_prime['Market Price'], label='observed', color='blue')
ax1.plot(ARIMA_predictions.predicted_mean[-len(X_test):], label='predicted', color='red')
ax1.fill_between(ARIMA_predictionsci.index[-len(X_test):], lower_ci[-len(X_test):], upper_ci[-len(X_test):], color='pink')
ax1.set_xlabel('Date')
ax1.set_ylabel('Values')
ax1.set_title('Stationary Predictions')

ax2.plot(monthly_pca_bitcoin_df['Market Price'], label='observed', color='blue')
ax2.plot((ARIMA_predictions_orig[-len(X_test):] + monthly_pca_bitcoin_df['Market Price'].iloc[int(len(X_univar) * 0.8)]), label='predicted', color='red')
ax2.set_xlabel('Date')
ax2.set_ylabel('Values in $s')
ax2.set_title('Original Values Predictions')

ax3.plot((ARIMA_predictions_orig[-len(X_test):] + monthly_pca_bitcoin_df['Market Price'].iloc[int(len(X_univar) * 0.8)]), color='red', label='predicted')
ax3.set_xlabel('Date')
ax3.set_ylabel('Values in $s')
ax3.set_title('Predictions')

plt.suptitle('Observed vs. Prediction')
plt.legend()
plt.show()

# %% [markdown]
# So interesting results here from the model predictions.  When left visually with the stationary time-series, the line seems to move to predict what the next value problably is, when including the area included within the Confidence interval range, the true values all fall within this confidence interval, which is a good thing.  However when we return the Time series to their original values and transform the predictions to match, it looks just like a straight line. and when we look closer it appears to be a very low exponential curve happening here.  There is a very broad degree of variability happening which a simple univariate model won't be able to capture it seems so thus, we will try an LSTM model next and see if it performs any better.

# %% [markdown]
# - ##### LSTM MODELS #####
# ***

# %%
for col in X_prime.columns:
    sns.displot(X_prime[col])

# %% [markdown]
# Good news! data is fairly normally distributed with a few outliers, so without further ado, we are good to continue creating our LSTM, Also it turns out the LSTM Models don't require stationary data so we will create a new LSTM_prime variabel which has the original data from the initially imported DataFrames

# %%
monthly_pca_bitcoin_df.head()
# Out:
#                 PCA1      PCA2      PCA3      PCA4      PCA5      PCA6  \
# date
# 2010-09-30 -4.139563 -1.782462  0.454551 -0.442915 -0.062848 -0.082861
# 2010-10-31 -4.113286 -1.785291  0.463001 -0.421634 -0.054172 -0.110956
# 2010-11-30 -4.107214 -1.733388  0.450317 -0.378658 -0.079583 -0.034921
# 2010-12-31 -4.090439 -1.780404  0.442663 -0.445379 -0.039219 -0.159515
# 2011-01-31 -4.081305 -1.713802  0.431579 -0.381060 -0.068381 -0.066733
#
#                 PCA7      PCA8      PCA9     PCA10     PCA11     PCA12  \
# date
# 2010-09-30  0.165154  0.161381 -0.533707 -0.075476  0.144298 -0.077008
# 2010-10-31  0.171544  0.151653 -0.517539 -0.059395  0.101462 -0.075337
# 2010-11-30  0.115946  0.074011 -0.546958 -0.053924  0.081190 -0.063967
# 2010-12-31  0.196844  0.184849 -0.484988 -0.059855  0.088238 -0.062100
# 2011-01-31  0.133499  0.131493 -0.524707 -0.060113  0.069921 -0.052373
#
#             Market Price  PCA1_stationary  PCA2_stationary  PCA6_stationary  \
# date
# 2010-09-30         0.062        -0.010336         0.010967        -0.010012
# 2010-10-31         0.190        -0.011741        -0.002829        -0.028095
# 2010-11-30         0.280        -0.010639         0.051903         0.076035
# 2010-12-31         0.300        -0.011938        -0.047017        -0.124594
# 2011-01-31         0.950        -0.007806         0.066603         0.092782
#
#             Market Price_stationary
# date
# 2010-09-30                -0.045713
# 2010-10-31                 1.119890
# 2010-11-30                 0.387766
# 2010-12-31                 0.068993
# 2011-01-31                 1.152680

# %%
monthly_pca_bitcoin_df.columns[:13]
# Out:
# Index(['PCA1', 'PCA2', 'PCA3', 'PCA4', 'PCA5', 'PCA6', 'PCA7', 'PCA8', 'PCA9',
#        'PCA10', 'PCA11', 'PCA12', 'Market Price'],
#       dtype='object')

# %%
scaler = MinMaxScaler()

LSTM_X_prime = scaler.fit_transform(monthly_pca_bitcoin_df[monthly_pca_bitcoin_df.columns[:13]])

# %%
plt.plot(LSTM_X_prime[:,12])

# %%
#########################
# LSTM MODELING FUNCTIONS
#########################
def to_X_y(array, window=5):
    #array = df.to_numpy()
    X = []
    y = []
    for i in range(len(array) - window):
        row = [k[:len(k)] for k in array[i: i + window,: -1]]
        X.append(row)
        label = array[i + window, -1]
        y.append(label)
        
    return np.array(X), np.array(y)


def train_test_val_split(X, y, train_length=0.75, val_length=0.15, test_length=0.10):
    # X, y train
    X_train, y_train = X[:int(round(len(X) * train_length))], y[:int(round(len(y) * train_length))]
    
    # X, y val
    X_val, y_val = X[:int(round(len(X) * val_length))], y[:int(round(len(y) * val_length))]
    
    # X, y test
    X_test, y_test = X[:int(round(len(X) * test_length))], y[:int(round(len(y) * test_length))]
    
    return X_train, y_train, X_val, y_val, X_test, y_test


def df_convert_pred(source_series, predictions):
    '''predictions must be completed all the way until the end,
        no middle predictions yet!'''
    div_value = len(source_series) - len(predictions)
    fill_list = []

    for i in range(div_value):
        fill_list.append(np.NaN)

    new_pred = np.concatenate([np.array(fill_list), predictions])

    return pd.DataFrame({'Observed': source_series, 'Predictions': new_pred})
    
    
def results_original_scale(source_array, predictions, scaler, index, window=5):
    '''
    a function for restoring observed and predicted data to original scale prior to visualizing.
    the predictions variable needs to have DateTime as its index
    '''
    # create a temp_array for both reverse transformations for predictions and observed data.
    temp_array = copy.copy(source_array)
    
    # Concatenate all Dfs
    results_df = df_convert_pred(source_array[:,12], predictions).set_index(index)

    # Assign the predictions to temp_array
    temp_array[:,12] = results_df['Predictions']

    # inverse_transform predictions and observed data.
    predicted = scaler.inverse_transform(temp_array)[window:, 12]
    observed = scaler.inverse_transform(source_array)[window:, 12]

    # return the results in a DataFrame
    return pd.DataFrame({'Observed': observed, 'Predictions': predicted}).set_index(index[window:])

# %%
# Divide Data into X, y for Train, val and Test data
Window = 5
LSTM_X, LSTM_y = to_X_y(LSTM_X_prime, window=Window)
LSTM_X_train, LSTM_y_train, LSTM_X_val, LSTM_y_val, LSTM_X_test, LSTM_y_test = train_test_val_split(LSTM_X, LSTM_y)

# %%
print(f'Train_X: {LSTM_X_train.shape}\nTrain_y: {LSTM_y_train.shape}\nVal_X: {LSTM_X_val.shape}\nVal_y: {LSTM_y_val.shape}\nTest_X: {LSTM_X_test.shape}\nTest_y: {LSTM_y_test.shape}')
# Out:
# Train_X: (120, 5, 12)
# Train_y: (120,)
# Val_X: (24, 5, 12)
# Val_y: (24,)
# Test_X: (16, 5, 12)
# Test_y: (16,)

# %% [markdown]
# Now we can proceed to build the Multivariate LSTM Model

# %%
model = Sequential()
model.add(LSTM(250, input_shape=(LSTM_X_train.shape[1], LSTM_X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(12))
model.add(Dense(1))
model.compile(loss=MeanAbsoluteError(), metrics=RootMeanSquaredError(), optimizer=Adam())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 250)               263000
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense (Dense)               (None, 12)                3012
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 266,025
# Trainable params: 266,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(LSTM_X_train,
                    LSTM_y_train,
                    epochs=250,
                    batch_size=72,
                    validation_data=(LSTM_X_val, LSTM_y_val),
                    verbose=2,
                    shuffle=False)
# Out:
# Epoch 1/250
# 2/2 - 2s - loss: 0.1937 - root_mean_squared_error: 0.2414 - val_loss: 0.1548 - val_root_mean_squared_error: 0.1557 - 2s/epoch - 826ms/step
# Epoch 2/250
# 2/2 - 0s - loss: 0.1773 - root_mean_squared_error: 0.1915 - val_loss: 0.1011 - val_root_mean_squared_error: 0.1012 - 49ms/epoch - 24ms/step
# Epoch 3/250
# 2/2 - 0s - loss: 0.0978 - root_mean_squared_error: 0.1123 - val_loss: 0.1590 - val_root_mean_squared_error: 0.1590 - 27ms/epoch - 13ms/step
# Epoch 4/250
# 2/2 - 0s - loss: 0.1222 - root_mean_squared_error: 0.1410 - val_loss: 0.0661 - val_root_mean_squared_error: 0.0661 - 27ms/epoch - 14ms/step
# Epoch 5/250
# 2/2 - 0s - loss: 0.0785 - root_mean_squared_error: 0.1032 - val_loss: 0.0373 - val_root_mean_squared_error: 0.0376 - 66ms/epoch - 33ms/step
# Epoch 6/250
# 2/2 - 0s - loss: 0.0836 - root_mean_squared_error: 0.1131 - val_loss: 0.0163 - val_root_mean_squared_error: 0.0165 - 60ms/epoch - 30ms/step
# Epoch 7/250
# 2/2 - 0s - loss: 0.0524 - root_mean_squared_error: 0.0808 - val_loss: 0.0547 - val_root_mean_squared_error: 0.0548 - 27ms/epoch - 13ms/step
# Epoch 8/250
# 2/2 - 0s - loss: 0.0600 - root_mean_squared_error: 0.0758 - val_loss: 0.0769 - val_root_mean_squared_error: 0.0771 - 27ms/epoch - 14ms/step
# Epoch 9/250
# 2/2 - 0s - loss: 0.0817 - root_mean_squared_error: 0.0968 - val_loss: 0.0391 - val_root_mean_squared_error: 0.0393 - 27ms/epoch - 14ms/step
# Epoch 10/250
# 2/2 - 0s - loss: 0.0599 - root_mean_squared_error: 0.0854 - val_loss: 0.0136 - val_root_mean_squared_error: 0.0138 - 26ms/epoch - 13ms/step
# Epoch 11/250
# 2/2 - 0s - loss: 0.0504 - root_mean_squared_error: 0.0796 - val_loss: 0.0304 - val_root_mean_squared_error: 0.0305 - 26ms/epoch - 13ms/step
# Epoch 12/250
# 2/2 - 0s - loss: 0.0492 - root_mean_squared_error: 0.0723 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0040 - 26ms/epoch - 13ms/step
# Epoch 13/250
# 2/2 - 0s - loss: 0.0441 - root_mean_squared_error: 0.0693 - val_loss: 0.0215 - val_root_mean_squared_error: 0.0222 - 26ms/epoch - 13ms/step
# Epoch 14/250
# 2/2 - 0s - loss: 0.0513 - root_mean_squared_error: 0.0675 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0053 - 29ms/epoch - 15ms/step
# Epoch 15/250
# 2/2 - 0s - loss: 0.0408 - root_mean_squared_error: 0.0587 - val_loss: 0.0273 - val_root_mean_squared_error: 0.0277 - 26ms/epoch - 13ms/step
# Epoch 16/250
# 2/2 - 0s - loss: 0.0430 - root_mean_squared_error: 0.0661 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0355 - 60ms/epoch - 30ms/step
# Epoch 17/250
# 2/2 - 0s - loss: 0.0471 - root_mean_squared_error: 0.0646 - val_loss: 0.0235 - val_root_mean_squared_error: 0.0242 - 27ms/epoch - 13ms/step
# Epoch 18/250
# 2/2 - 0s - loss: 0.0429 - root_mean_squared_error: 0.0651 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0159 - 26ms/epoch - 13ms/step
# Epoch 19/250
# 2/2 - 0s - loss: 0.0414 - root_mean_squared_error: 0.0603 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0160 - 25ms/epoch - 13ms/step
# Epoch 20/250
# 2/2 - 0s - loss: 0.0371 - root_mean_squared_error: 0.0577 - val_loss: 0.0209 - val_root_mean_squared_error: 0.0216 - 28ms/epoch - 14ms/step
# Epoch 21/250
# 2/2 - 0s - loss: 0.0378 - root_mean_squared_error: 0.0582 - val_loss: 0.0181 - val_root_mean_squared_error: 0.0189 - 26ms/epoch - 13ms/step
# Epoch 22/250
# 2/2 - 0s - loss: 0.0391 - root_mean_squared_error: 0.0587 - val_loss: 0.0146 - val_root_mean_squared_error: 0.0154 - 30ms/epoch - 15ms/step
# Epoch 23/250
# 2/2 - 0s - loss: 0.0364 - root_mean_squared_error: 0.0600 - val_loss: 0.0167 - val_root_mean_squared_error: 0.0174 - 26ms/epoch - 13ms/step
# Epoch 24/250
# 2/2 - 0s - loss: 0.0352 - root_mean_squared_error: 0.0551 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0092 - 26ms/epoch - 13ms/step
# Epoch 25/250
# 2/2 - 0s - loss: 0.0379 - root_mean_squared_error: 0.0604 - val_loss: 0.0181 - val_root_mean_squared_error: 0.0187 - 26ms/epoch - 13ms/step
# Epoch 26/250
# 2/2 - 0s - loss: 0.0349 - root_mean_squared_error: 0.0552 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0072 - 26ms/epoch - 13ms/step
# Epoch 27/250
# 2/2 - 0s - loss: 0.0360 - root_mean_squared_error: 0.0564 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0056 - 26ms/epoch - 13ms/step
# Epoch 28/250
# 2/2 - 0s - loss: 0.0339 - root_mean_squared_error: 0.0516 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0088 - 25ms/epoch - 13ms/step
# Epoch 29/250
# 2/2 - 0s - loss: 0.0352 - root_mean_squared_error: 0.0627 - val_loss: 0.0173 - val_root_mean_squared_error: 0.0179 - 44ms/epoch - 22ms/step
# Epoch 30/250
# 2/2 - 0s - loss: 0.0325 - root_mean_squared_error: 0.0530 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0132 - 25ms/epoch - 13ms/step
# Epoch 31/250
# 2/2 - 0s - loss: 0.0359 - root_mean_squared_error: 0.0521 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0061 - 61ms/epoch - 31ms/step
# Epoch 32/250
# 2/2 - 0s - loss: 0.0321 - root_mean_squared_error: 0.0535 - val_loss: 0.0162 - val_root_mean_squared_error: 0.0169 - 26ms/epoch - 13ms/step
# Epoch 33/250
# 2/2 - 0s - loss: 0.0329 - root_mean_squared_error: 0.0549 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0105 - 26ms/epoch - 13ms/step
# Epoch 34/250
# 2/2 - 0s - loss: 0.0321 - root_mean_squared_error: 0.0543 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0067 - 25ms/epoch - 13ms/step
# Epoch 35/250
# 2/2 - 0s - loss: 0.0298 - root_mean_squared_error: 0.0533 - val_loss: 0.0240 - val_root_mean_squared_error: 0.0246 - 59ms/epoch - 29ms/step
# Epoch 36/250
# 2/2 - 0s - loss: 0.0293 - root_mean_squared_error: 0.0500 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0078 - 26ms/epoch - 13ms/step
# Epoch 37/250
# 2/2 - 0s - loss: 0.0305 - root_mean_squared_error: 0.0491 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0062 - 26ms/epoch - 13ms/step
# Epoch 38/250
# 2/2 - 0s - loss: 0.0283 - root_mean_squared_error: 0.0481 - val_loss: 0.0203 - val_root_mean_squared_error: 0.0210 - 26ms/epoch - 13ms/step
# Epoch 39/250
# 2/2 - 0s - loss: 0.0290 - root_mean_squared_error: 0.0476 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0119 - 48ms/epoch - 24ms/step
# Epoch 40/250
# 2/2 - 0s - loss: 0.0289 - root_mean_squared_error: 0.0468 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0062 - 26ms/epoch - 13ms/step
# Epoch 41/250
# 2/2 - 0s - loss: 0.0287 - root_mean_squared_error: 0.0531 - val_loss: 0.0285 - val_root_mean_squared_error: 0.0290 - 26ms/epoch - 13ms/step
# Epoch 42/250
# 2/2 - 0s - loss: 0.0326 - root_mean_squared_error: 0.0492 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0097 - 26ms/epoch - 13ms/step
# Epoch 43/250
# 2/2 - 0s - loss: 0.0294 - root_mean_squared_error: 0.0480 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0078 - 25ms/epoch - 13ms/step
# Epoch 44/250
# 2/2 - 0s - loss: 0.0271 - root_mean_squared_error: 0.0503 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0234 - 27ms/epoch - 13ms/step
# Epoch 45/250
# 2/2 - 0s - loss: 0.0299 - root_mean_squared_error: 0.0459 - val_loss: 0.0160 - val_root_mean_squared_error: 0.0165 - 26ms/epoch - 13ms/step
# Epoch 46/250
# 2/2 - 0s - loss: 0.0309 - root_mean_squared_error: 0.0476 - val_loss: 0.0177 - val_root_mean_squared_error: 0.0179 - 27ms/epoch - 13ms/step
# Epoch 47/250
# 2/2 - 0s - loss: 0.0271 - root_mean_squared_error: 0.0486 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0050 - 61ms/epoch - 31ms/step
# Epoch 48/250
# 2/2 - 0s - loss: 0.0272 - root_mean_squared_error: 0.0472 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0046 - 26ms/epoch - 13ms/step
# Epoch 49/250
# 2/2 - 0s - loss: 0.0270 - root_mean_squared_error: 0.0487 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0117 - 26ms/epoch - 13ms/step
# Epoch 50/250
# 2/2 - 0s - loss: 0.0234 - root_mean_squared_error: 0.0423 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0112 - 26ms/epoch - 13ms/step
# Epoch 51/250
# 2/2 - 0s - loss: 0.0258 - root_mean_squared_error: 0.0475 - val_loss: 0.0179 - val_root_mean_squared_error: 0.0181 - 26ms/epoch - 13ms/step
# Epoch 52/250
# 2/2 - 0s - loss: 0.0280 - root_mean_squared_error: 0.0470 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0032 - 26ms/epoch - 13ms/step
# Epoch 53/250
# 2/2 - 0s - loss: 0.0243 - root_mean_squared_error: 0.0444 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0048 - 27ms/epoch - 14ms/step
# Epoch 54/250
# 2/2 - 0s - loss: 0.0243 - root_mean_squared_error: 0.0457 - val_loss: 0.0221 - val_root_mean_squared_error: 0.0222 - 26ms/epoch - 13ms/step
# Epoch 55/250
# 2/2 - 0s - loss: 0.0278 - root_mean_squared_error: 0.0448 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0071 - 27ms/epoch - 14ms/step
# Epoch 56/250
# 2/2 - 0s - loss: 0.0250 - root_mean_squared_error: 0.0454 - val_loss: 0.0235 - val_root_mean_squared_error: 0.0236 - 26ms/epoch - 13ms/step
# Epoch 57/250
# 2/2 - 0s - loss: 0.0302 - root_mean_squared_error: 0.0487 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0136 - 26ms/epoch - 13ms/step
# Epoch 58/250
# 2/2 - 0s - loss: 0.0273 - root_mean_squared_error: 0.0462 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0048 - 26ms/epoch - 13ms/step
# Epoch 59/250
# 2/2 - 0s - loss: 0.0219 - root_mean_squared_error: 0.0425 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0035 - 62ms/epoch - 31ms/step
# Epoch 60/250
# 2/2 - 0s - loss: 0.0216 - root_mean_squared_error: 0.0407 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0089 - 26ms/epoch - 13ms/step
# Epoch 61/250
# 2/2 - 0s - loss: 0.0209 - root_mean_squared_error: 0.0417 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0128 - 26ms/epoch - 13ms/step
# Epoch 62/250
# 2/2 - 0s - loss: 0.0242 - root_mean_squared_error: 0.0409 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0052 - 26ms/epoch - 13ms/step
# Epoch 63/250
# 2/2 - 0s - loss: 0.0224 - root_mean_squared_error: 0.0458 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0135 - 25ms/epoch - 13ms/step
# Epoch 64/250
# 2/2 - 0s - loss: 0.0221 - root_mean_squared_error: 0.0412 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0046 - 26ms/epoch - 13ms/step
# Epoch 65/250
# 2/2 - 0s - loss: 0.0201 - root_mean_squared_error: 0.0415 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0085 - 26ms/epoch - 13ms/step
# Epoch 66/250
# 2/2 - 0s - loss: 0.0213 - root_mean_squared_error: 0.0420 - val_loss: 0.0159 - val_root_mean_squared_error: 0.0164 - 26ms/epoch - 13ms/step
# Epoch 67/250
# 2/2 - 0s - loss: 0.0260 - root_mean_squared_error: 0.0448 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0079 - 26ms/epoch - 13ms/step
# Epoch 68/250
# 2/2 - 0s - loss: 0.0218 - root_mean_squared_error: 0.0407 - val_loss: 0.0194 - val_root_mean_squared_error: 0.0198 - 26ms/epoch - 13ms/step
# Epoch 69/250
# 2/2 - 0s - loss: 0.0243 - root_mean_squared_error: 0.0414 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0110 - 26ms/epoch - 13ms/step
# Epoch 70/250
# 2/2 - 0s - loss: 0.0196 - root_mean_squared_error: 0.0421 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0046 - 26ms/epoch - 13ms/step
# Epoch 71/250
# 2/2 - 0s - loss: 0.0194 - root_mean_squared_error: 0.0386 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0071 - 25ms/epoch - 13ms/step
# Epoch 72/250
# 2/2 - 0s - loss: 0.0205 - root_mean_squared_error: 0.0401 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0048 - 26ms/epoch - 13ms/step
# Epoch 73/250
# 2/2 - 0s - loss: 0.0198 - root_mean_squared_error: 0.0378 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0047 - 58ms/epoch - 29ms/step
# Epoch 74/250
# 2/2 - 0s - loss: 0.0176 - root_mean_squared_error: 0.0377 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0046 - 25ms/epoch - 13ms/step
# Epoch 75/250
# 2/2 - 0s - loss: 0.0192 - root_mean_squared_error: 0.0368 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0078 - 26ms/epoch - 13ms/step
# Epoch 76/250
# 2/2 - 0s - loss: 0.0203 - root_mean_squared_error: 0.0387 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0149 - 25ms/epoch - 13ms/step
# Epoch 77/250
# 2/2 - 0s - loss: 0.0268 - root_mean_squared_error: 0.0473 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0123 - 26ms/epoch - 13ms/step
# Epoch 78/250
# 2/2 - 0s - loss: 0.0222 - root_mean_squared_error: 0.0375 - val_loss: 0.0368 - val_root_mean_squared_error: 0.0371 - 49ms/epoch - 24ms/step
# Epoch 79/250
# 2/2 - 0s - loss: 0.0349 - root_mean_squared_error: 0.0482 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0062 - 27ms/epoch - 14ms/step
# Epoch 80/250
# 2/2 - 0s - loss: 0.0197 - root_mean_squared_error: 0.0405 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0064 - 26ms/epoch - 13ms/step
# Epoch 81/250
# 2/2 - 0s - loss: 0.0206 - root_mean_squared_error: 0.0364 - val_loss: 0.0136 - val_root_mean_squared_error: 0.0142 - 65ms/epoch - 33ms/step
# Epoch 82/250
# 2/2 - 0s - loss: 0.0252 - root_mean_squared_error: 0.0442 - val_loss: 0.0298 - val_root_mean_squared_error: 0.0300 - 26ms/epoch - 13ms/step
# Epoch 83/250
# 2/2 - 0s - loss: 0.0293 - root_mean_squared_error: 0.0435 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0103 - 25ms/epoch - 13ms/step
# Epoch 84/250
# 2/2 - 0s - loss: 0.0250 - root_mean_squared_error: 0.0401 - val_loss: 0.0221 - val_root_mean_squared_error: 0.0223 - 125ms/epoch - 62ms/step
# Epoch 85/250
# 2/2 - 0s - loss: 0.0225 - root_mean_squared_error: 0.0394 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0087 - 26ms/epoch - 13ms/step
# Epoch 86/250
# 2/2 - 0s - loss: 0.0195 - root_mean_squared_error: 0.0385 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0036 - 26ms/epoch - 13ms/step
# Epoch 87/250
# 2/2 - 0s - loss: 0.0201 - root_mean_squared_error: 0.0427 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0128 - 26ms/epoch - 13ms/step
# Epoch 88/250
# 2/2 - 0s - loss: 0.0194 - root_mean_squared_error: 0.0385 - val_loss: 0.0257 - val_root_mean_squared_error: 0.0260 - 26ms/epoch - 13ms/step
# Epoch 89/250
# 2/2 - 0s - loss: 0.0294 - root_mean_squared_error: 0.0447 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0079 - 26ms/epoch - 13ms/step
# Epoch 90/250
# 2/2 - 0s - loss: 0.0223 - root_mean_squared_error: 0.0457 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0138 - 27ms/epoch - 13ms/step
# Epoch 91/250
# 2/2 - 0s - loss: 0.0193 - root_mean_squared_error: 0.0378 - val_loss: 0.0194 - val_root_mean_squared_error: 0.0200 - 26ms/epoch - 13ms/step
# Epoch 92/250
# 2/2 - 0s - loss: 0.0251 - root_mean_squared_error: 0.0392 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0121 - 27ms/epoch - 13ms/step
# Epoch 93/250
# 2/2 - 0s - loss: 0.0196 - root_mean_squared_error: 0.0397 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0055 - 26ms/epoch - 13ms/step
# Epoch 94/250
# 2/2 - 0s - loss: 0.0185 - root_mean_squared_error: 0.0367 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0062 - 59ms/epoch - 30ms/step
# Epoch 95/250
# 2/2 - 0s - loss: 0.0186 - root_mean_squared_error: 0.0386 - val_loss: 0.0213 - val_root_mean_squared_error: 0.0217 - 26ms/epoch - 13ms/step
# Epoch 96/250
# 2/2 - 0s - loss: 0.0244 - root_mean_squared_error: 0.0410 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0054 - 26ms/epoch - 13ms/step
# Epoch 97/250
# 2/2 - 0s - loss: 0.0177 - root_mean_squared_error: 0.0354 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0079 - 26ms/epoch - 13ms/step
# Epoch 98/250
# 2/2 - 0s - loss: 0.0177 - root_mean_squared_error: 0.0391 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0063 - 61ms/epoch - 31ms/step
# Epoch 99/250
# 2/2 - 0s - loss: 0.0173 - root_mean_squared_error: 0.0372 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0072 - 26ms/epoch - 13ms/step
# Epoch 100/250
# 2/2 - 0s - loss: 0.0191 - root_mean_squared_error: 0.0395 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0132 - 26ms/epoch - 13ms/step
# Epoch 101/250
# 2/2 - 0s - loss: 0.0197 - root_mean_squared_error: 0.0376 - val_loss: 0.0156 - val_root_mean_squared_error: 0.0162 - 25ms/epoch - 13ms/step
# Epoch 102/250
# 2/2 - 0s - loss: 0.0224 - root_mean_squared_error: 0.0379 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0079 - 26ms/epoch - 13ms/step
# Epoch 103/250
# 2/2 - 0s - loss: 0.0180 - root_mean_squared_error: 0.0404 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0054 - 26ms/epoch - 13ms/step
# Epoch 104/250
# 2/2 - 0s - loss: 0.0166 - root_mean_squared_error: 0.0377 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0066 - 25ms/epoch - 13ms/step
# Epoch 105/250
# 2/2 - 0s - loss: 0.0183 - root_mean_squared_error: 0.0379 - val_loss: 0.0173 - val_root_mean_squared_error: 0.0178 - 63ms/epoch - 31ms/step
# Epoch 106/250
# 2/2 - 0s - loss: 0.0220 - root_mean_squared_error: 0.0376 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0045 - 27ms/epoch - 13ms/step
# Epoch 107/250
# 2/2 - 0s - loss: 0.0165 - root_mean_squared_error: 0.0328 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0060 - 26ms/epoch - 13ms/step
# Epoch 108/250
# 2/2 - 0s - loss: 0.0163 - root_mean_squared_error: 0.0362 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0089 - 27ms/epoch - 13ms/step
# Epoch 109/250
# 2/2 - 0s - loss: 0.0198 - root_mean_squared_error: 0.0389 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0082 - 26ms/epoch - 13ms/step
# Epoch 110/250
# 2/2 - 0s - loss: 0.0174 - root_mean_squared_error: 0.0378 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0082 - 26ms/epoch - 13ms/step
# Epoch 111/250
# 2/2 - 0s - loss: 0.0174 - root_mean_squared_error: 0.0362 - val_loss: 0.0223 - val_root_mean_squared_error: 0.0228 - 26ms/epoch - 13ms/step
# Epoch 112/250
# 2/2 - 0s - loss: 0.0255 - root_mean_squared_error: 0.0385 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0073 - 26ms/epoch - 13ms/step
# Epoch 113/250
# 2/2 - 0s - loss: 0.0200 - root_mean_squared_error: 0.0414 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0067 - 49ms/epoch - 24ms/step
# Epoch 114/250
# 2/2 - 0s - loss: 0.0152 - root_mean_squared_error: 0.0336 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0058 - 26ms/epoch - 13ms/step
# Epoch 115/250
# 2/2 - 0s - loss: 0.0167 - root_mean_squared_error: 0.0366 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0093 - 26ms/epoch - 13ms/step
# Epoch 116/250
# 2/2 - 0s - loss: 0.0177 - root_mean_squared_error: 0.0326 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0123 - 26ms/epoch - 13ms/step
# Epoch 117/250
# 2/2 - 0s - loss: 0.0203 - root_mean_squared_error: 0.0374 - val_loss: 0.0241 - val_root_mean_squared_error: 0.0245 - 26ms/epoch - 13ms/step
# Epoch 118/250
# 2/2 - 0s - loss: 0.0274 - root_mean_squared_error: 0.0430 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0053 - 26ms/epoch - 13ms/step
# Epoch 119/250
# 2/2 - 0s - loss: 0.0210 - root_mean_squared_error: 0.0369 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0063 - 26ms/epoch - 13ms/step
# Epoch 120/250
# 2/2 - 0s - loss: 0.0186 - root_mean_squared_error: 0.0379 - val_loss: 0.0221 - val_root_mean_squared_error: 0.0225 - 26ms/epoch - 13ms/step
# Epoch 121/250
# 2/2 - 0s - loss: 0.0247 - root_mean_squared_error: 0.0387 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0068 - 26ms/epoch - 13ms/step
# Epoch 122/250
# 2/2 - 0s - loss: 0.0176 - root_mean_squared_error: 0.0332 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0134 - 26ms/epoch - 13ms/step
# Epoch 123/250
# 2/2 - 0s - loss: 0.0195 - root_mean_squared_error: 0.0374 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0069 - 25ms/epoch - 13ms/step
# Epoch 124/250
# 2/2 - 0s - loss: 0.0177 - root_mean_squared_error: 0.0376 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0065 - 25ms/epoch - 13ms/step
# Epoch 125/250
# 2/2 - 0s - loss: 0.0151 - root_mean_squared_error: 0.0345 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0052 - 26ms/epoch - 13ms/step
# Epoch 126/250
# 2/2 - 0s - loss: 0.0158 - root_mean_squared_error: 0.0336 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0050 - 59ms/epoch - 30ms/step
# Epoch 127/250
# 2/2 - 0s - loss: 0.0147 - root_mean_squared_error: 0.0336 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0091 - 26ms/epoch - 13ms/step
# Epoch 128/250
# 2/2 - 0s - loss: 0.0180 - root_mean_squared_error: 0.0360 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0140 - 59ms/epoch - 30ms/step
# Epoch 129/250
# 2/2 - 0s - loss: 0.0195 - root_mean_squared_error: 0.0370 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0078 - 60ms/epoch - 30ms/step
# Epoch 130/250
# 2/2 - 0s - loss: 0.0194 - root_mean_squared_error: 0.0357 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0126 - 57ms/epoch - 29ms/step
# Epoch 131/250
# 2/2 - 0s - loss: 0.0183 - root_mean_squared_error: 0.0347 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0066 - 26ms/epoch - 13ms/step
# Epoch 132/250
# 2/2 - 0s - loss: 0.0159 - root_mean_squared_error: 0.0345 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0058 - 25ms/epoch - 13ms/step
# Epoch 133/250
# 2/2 - 0s - loss: 0.0157 - root_mean_squared_error: 0.0344 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0088 - 26ms/epoch - 13ms/step
# Epoch 134/250
# 2/2 - 0s - loss: 0.0166 - root_mean_squared_error: 0.0343 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0100 - 60ms/epoch - 30ms/step
# Epoch 135/250
# 2/2 - 0s - loss: 0.0176 - root_mean_squared_error: 0.0362 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0053 - 26ms/epoch - 13ms/step
# Epoch 136/250
# 2/2 - 0s - loss: 0.0158 - root_mean_squared_error: 0.0339 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0088 - 26ms/epoch - 13ms/step
# Epoch 137/250
# 2/2 - 0s - loss: 0.0164 - root_mean_squared_error: 0.0339 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0048 - 26ms/epoch - 13ms/step
# Epoch 138/250
# 2/2 - 0s - loss: 0.0156 - root_mean_squared_error: 0.0346 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0045 - 26ms/epoch - 13ms/step
# Epoch 139/250
# 2/2 - 0s - loss: 0.0157 - root_mean_squared_error: 0.0359 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0041 - 26ms/epoch - 13ms/step
# Epoch 140/250
# 2/2 - 0s - loss: 0.0151 - root_mean_squared_error: 0.0329 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0112 - 26ms/epoch - 13ms/step
# Epoch 141/250
# 2/2 - 0s - loss: 0.0184 - root_mean_squared_error: 0.0352 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0104 - 60ms/epoch - 30ms/step
# Epoch 142/250
# 2/2 - 0s - loss: 0.0170 - root_mean_squared_error: 0.0328 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0092 - 60ms/epoch - 30ms/step
# Epoch 143/250
# 2/2 - 0s - loss: 0.0177 - root_mean_squared_error: 0.0331 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0112 - 27ms/epoch - 14ms/step
# Epoch 144/250
# 2/2 - 0s - loss: 0.0188 - root_mean_squared_error: 0.0356 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0116 - 26ms/epoch - 13ms/step
# Epoch 145/250
# 2/2 - 0s - loss: 0.0194 - root_mean_squared_error: 0.0343 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0102 - 55ms/epoch - 28ms/step
# Epoch 146/250
# 2/2 - 0s - loss: 0.0174 - root_mean_squared_error: 0.0374 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0081 - 75ms/epoch - 37ms/step
# Epoch 147/250
# 2/2 - 0s - loss: 0.0166 - root_mean_squared_error: 0.0348 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0070 - 93ms/epoch - 46ms/step
# Epoch 148/250
# 2/2 - 0s - loss: 0.0169 - root_mean_squared_error: 0.0371 - val_loss: 0.0153 - val_root_mean_squared_error: 0.0159 - 26ms/epoch - 13ms/step
# Epoch 149/250
# 2/2 - 0s - loss: 0.0199 - root_mean_squared_error: 0.0331 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0106 - 26ms/epoch - 13ms/step
# Epoch 150/250
# 2/2 - 0s - loss: 0.0188 - root_mean_squared_error: 0.0325 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0091 - 26ms/epoch - 13ms/step
# Epoch 151/250
# 2/2 - 0s - loss: 0.0169 - root_mean_squared_error: 0.0347 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0074 - 58ms/epoch - 29ms/step
# Epoch 152/250
# 2/2 - 0s - loss: 0.0159 - root_mean_squared_error: 0.0322 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0065 - 27ms/epoch - 13ms/step
# Epoch 153/250
# 2/2 - 0s - loss: 0.0156 - root_mean_squared_error: 0.0352 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0110 - 65ms/epoch - 33ms/step
# Epoch 154/250
# 2/2 - 0s - loss: 0.0191 - root_mean_squared_error: 0.0365 - val_loss: 0.0150 - val_root_mean_squared_error: 0.0159 - 65ms/epoch - 32ms/step
# Epoch 155/250
# 2/2 - 0s - loss: 0.0197 - root_mean_squared_error: 0.0343 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0049 - 26ms/epoch - 13ms/step
# Epoch 156/250
# 2/2 - 0s - loss: 0.0165 - root_mean_squared_error: 0.0368 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0082 - 26ms/epoch - 13ms/step
# Epoch 157/250
# 2/2 - 0s - loss: 0.0160 - root_mean_squared_error: 0.0344 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0048 - 59ms/epoch - 29ms/step
# Epoch 158/250
# 2/2 - 0s - loss: 0.0152 - root_mean_squared_error: 0.0351 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0048 - 27ms/epoch - 13ms/step
# Epoch 159/250
# 2/2 - 0s - loss: 0.0143 - root_mean_squared_error: 0.0330 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0070 - 26ms/epoch - 13ms/step
# Epoch 160/250
# 2/2 - 0s - loss: 0.0156 - root_mean_squared_error: 0.0348 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0174 - 26ms/epoch - 13ms/step
# Epoch 161/250
# 2/2 - 0s - loss: 0.0213 - root_mean_squared_error: 0.0367 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0050 - 26ms/epoch - 13ms/step
# Epoch 162/250
# 2/2 - 0s - loss: 0.0158 - root_mean_squared_error: 0.0322 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0057 - 62ms/epoch - 31ms/step
# Epoch 163/250
# 2/2 - 0s - loss: 0.0144 - root_mean_squared_error: 0.0330 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0045 - 27ms/epoch - 13ms/step
# Epoch 164/250
# 2/2 - 0s - loss: 0.0148 - root_mean_squared_error: 0.0323 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0056 - 26ms/epoch - 13ms/step
# Epoch 165/250
# 2/2 - 0s - loss: 0.0152 - root_mean_squared_error: 0.0335 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0044 - 26ms/epoch - 13ms/step
# Epoch 166/250
# 2/2 - 0s - loss: 0.0150 - root_mean_squared_error: 0.0351 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0053 - 61ms/epoch - 30ms/step
# Epoch 167/250
# 2/2 - 0s - loss: 0.0154 - root_mean_squared_error: 0.0333 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0105 - 27ms/epoch - 13ms/step
# Epoch 168/250
# 2/2 - 0s - loss: 0.0178 - root_mean_squared_error: 0.0336 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0105 - 26ms/epoch - 13ms/step
# Epoch 169/250
# 2/2 - 0s - loss: 0.0184 - root_mean_squared_error: 0.0335 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0132 - 26ms/epoch - 13ms/step
# Epoch 170/250
# 2/2 - 0s - loss: 0.0198 - root_mean_squared_error: 0.0357 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0103 - 26ms/epoch - 13ms/step
# Epoch 171/250
# 2/2 - 0s - loss: 0.0173 - root_mean_squared_error: 0.0343 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0057 - 26ms/epoch - 13ms/step
# Epoch 172/250
# 2/2 - 0s - loss: 0.0155 - root_mean_squared_error: 0.0350 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0055 - 26ms/epoch - 13ms/step
# Epoch 173/250
# 2/2 - 0s - loss: 0.0140 - root_mean_squared_error: 0.0324 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0058 - 27ms/epoch - 14ms/step
# Epoch 174/250
# 2/2 - 0s - loss: 0.0148 - root_mean_squared_error: 0.0335 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0136 - 26ms/epoch - 13ms/step
# Epoch 175/250
# 2/2 - 0s - loss: 0.0188 - root_mean_squared_error: 0.0322 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0057 - 26ms/epoch - 13ms/step
# Epoch 176/250
# 2/2 - 0s - loss: 0.0153 - root_mean_squared_error: 0.0330 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0066 - 26ms/epoch - 13ms/step
# Epoch 177/250
# 2/2 - 0s - loss: 0.0161 - root_mean_squared_error: 0.0333 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0087 - 26ms/epoch - 13ms/step
# Epoch 178/250
# 2/2 - 0s - loss: 0.0152 - root_mean_squared_error: 0.0342 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0071 - 26ms/epoch - 13ms/step
# Epoch 179/250
# 2/2 - 0s - loss: 0.0160 - root_mean_squared_error: 0.0327 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0116 - 29ms/epoch - 14ms/step
# Epoch 180/250
# 2/2 - 0s - loss: 0.0162 - root_mean_squared_error: 0.0307 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0049 - 30ms/epoch - 15ms/step
# Epoch 181/250
# 2/2 - 0s - loss: 0.0145 - root_mean_squared_error: 0.0313 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0097 - 60ms/epoch - 30ms/step
# Epoch 182/250
# 2/2 - 0s - loss: 0.0172 - root_mean_squared_error: 0.0334 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0112 - 59ms/epoch - 30ms/step
# Epoch 183/250
# 2/2 - 0s - loss: 0.0177 - root_mean_squared_error: 0.0340 - val_loss: 0.0139 - val_root_mean_squared_error: 0.0145 - 70ms/epoch - 35ms/step
# Epoch 184/250
# 2/2 - 0s - loss: 0.0213 - root_mean_squared_error: 0.0321 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0040 - 57ms/epoch - 29ms/step
# Epoch 185/250
# 2/2 - 0s - loss: 0.0136 - root_mean_squared_error: 0.0323 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0143 - 25ms/epoch - 13ms/step
# Epoch 186/250
# 2/2 - 0s - loss: 0.0190 - root_mean_squared_error: 0.0311 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0110 - 26ms/epoch - 13ms/step
# Epoch 187/250
# 2/2 - 0s - loss: 0.0198 - root_mean_squared_error: 0.0325 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0126 - 61ms/epoch - 31ms/step
# Epoch 188/250
# 2/2 - 0s - loss: 0.0179 - root_mean_squared_error: 0.0343 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0046 - 27ms/epoch - 13ms/step
# Epoch 189/250
# 2/2 - 0s - loss: 0.0150 - root_mean_squared_error: 0.0314 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0097 - 26ms/epoch - 13ms/step
# Epoch 190/250
# 2/2 - 0s - loss: 0.0176 - root_mean_squared_error: 0.0365 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0081 - 27ms/epoch - 13ms/step
# Epoch 191/250
# 2/2 - 0s - loss: 0.0161 - root_mean_squared_error: 0.0304 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0125 - 27ms/epoch - 14ms/step
# Epoch 192/250
# 2/2 - 0s - loss: 0.0182 - root_mean_squared_error: 0.0313 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0063 - 26ms/epoch - 13ms/step
# Epoch 193/250
# 2/2 - 0s - loss: 0.0153 - root_mean_squared_error: 0.0328 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0067 - 62ms/epoch - 31ms/step
# Epoch 194/250
# 2/2 - 0s - loss: 0.0146 - root_mean_squared_error: 0.0314 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0106 - 27ms/epoch - 13ms/step
# Epoch 195/250
# 2/2 - 0s - loss: 0.0181 - root_mean_squared_error: 0.0354 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0075 - 26ms/epoch - 13ms/step
# Epoch 196/250
# 2/2 - 0s - loss: 0.0148 - root_mean_squared_error: 0.0332 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0101 - 26ms/epoch - 13ms/step
# Epoch 197/250
# 2/2 - 0s - loss: 0.0165 - root_mean_squared_error: 0.0305 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0056 - 26ms/epoch - 13ms/step
# Epoch 198/250
# 2/2 - 0s - loss: 0.0153 - root_mean_squared_error: 0.0347 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0052 - 26ms/epoch - 13ms/step
# Epoch 199/250
# 2/2 - 0s - loss: 0.0134 - root_mean_squared_error: 0.0290 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0062 - 26ms/epoch - 13ms/step
# Epoch 200/250
# 2/2 - 0s - loss: 0.0143 - root_mean_squared_error: 0.0291 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0051 - 26ms/epoch - 13ms/step
# Epoch 201/250
# 2/2 - 0s - loss: 0.0142 - root_mean_squared_error: 0.0318 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0088 - 26ms/epoch - 13ms/step
# Epoch 202/250
# 2/2 - 0s - loss: 0.0149 - root_mean_squared_error: 0.0293 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0065 - 26ms/epoch - 13ms/step
# Epoch 203/250
# 2/2 - 0s - loss: 0.0150 - root_mean_squared_error: 0.0296 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0060 - 26ms/epoch - 13ms/step
# Epoch 204/250
# 2/2 - 0s - loss: 0.0144 - root_mean_squared_error: 0.0320 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0108 - 26ms/epoch - 13ms/step
# Epoch 205/250
# 2/2 - 0s - loss: 0.0161 - root_mean_squared_error: 0.0301 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0041 - 26ms/epoch - 13ms/step
# Epoch 206/250
# 2/2 - 0s - loss: 0.0136 - root_mean_squared_error: 0.0299 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0055 - 61ms/epoch - 30ms/step
# Epoch 207/250
# 2/2 - 0s - loss: 0.0142 - root_mean_squared_error: 0.0300 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0050 - 26ms/epoch - 13ms/step
# Epoch 208/250
# 2/2 - 0s - loss: 0.0138 - root_mean_squared_error: 0.0286 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0104 - 31ms/epoch - 16ms/step
# Epoch 209/250
# 2/2 - 0s - loss: 0.0168 - root_mean_squared_error: 0.0287 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0111 - 26ms/epoch - 13ms/step
# Epoch 210/250
# 2/2 - 0s - loss: 0.0158 - root_mean_squared_error: 0.0291 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0047 - 26ms/epoch - 13ms/step
# Epoch 211/250
# 2/2 - 0s - loss: 0.0150 - root_mean_squared_error: 0.0327 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0071 - 26ms/epoch - 13ms/step
# Epoch 212/250
# 2/2 - 0s - loss: 0.0144 - root_mean_squared_error: 0.0278 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0046 - 26ms/epoch - 13ms/step
# Epoch 213/250
# 2/2 - 0s - loss: 0.0135 - root_mean_squared_error: 0.0307 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0052 - 25ms/epoch - 13ms/step
# Epoch 214/250
# 2/2 - 0s - loss: 0.0143 - root_mean_squared_error: 0.0279 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0064 - 29ms/epoch - 15ms/step
# Epoch 215/250
# 2/2 - 0s - loss: 0.0137 - root_mean_squared_error: 0.0270 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0065 - 36ms/epoch - 18ms/step
# Epoch 216/250
# 2/2 - 0s - loss: 0.0141 - root_mean_squared_error: 0.0272 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0095 - 26ms/epoch - 13ms/step
# Epoch 217/250
# 2/2 - 0s - loss: 0.0161 - root_mean_squared_error: 0.0303 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0038 - 27ms/epoch - 13ms/step
# Epoch 218/250
# 2/2 - 0s - loss: 0.0134 - root_mean_squared_error: 0.0310 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0059 - 25ms/epoch - 13ms/step
# Epoch 219/250
# 2/2 - 0s - loss: 0.0143 - root_mean_squared_error: 0.0309 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0045 - 26ms/epoch - 13ms/step
# Epoch 220/250
# 2/2 - 0s - loss: 0.0131 - root_mean_squared_error: 0.0299 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0043 - 26ms/epoch - 13ms/step
# Epoch 221/250
# 2/2 - 0s - loss: 0.0137 - root_mean_squared_error: 0.0255 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0060 - 26ms/epoch - 13ms/step
# Epoch 222/250
# 2/2 - 0s - loss: 0.0136 - root_mean_squared_error: 0.0283 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0075 - 26ms/epoch - 13ms/step
# Epoch 223/250
# 2/2 - 0s - loss: 0.0144 - root_mean_squared_error: 0.0281 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0051 - 25ms/epoch - 13ms/step
# Epoch 224/250
# 2/2 - 0s - loss: 0.0137 - root_mean_squared_error: 0.0317 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0040 - 26ms/epoch - 13ms/step
# Epoch 225/250
# 2/2 - 0s - loss: 0.0144 - root_mean_squared_error: 0.0314 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0137 - 26ms/epoch - 13ms/step
# Epoch 226/250
# 2/2 - 0s - loss: 0.0167 - root_mean_squared_error: 0.0324 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0041 - 26ms/epoch - 13ms/step
# Epoch 227/250
# 2/2 - 0s - loss: 0.0139 - root_mean_squared_error: 0.0294 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0056 - 26ms/epoch - 13ms/step
# Epoch 228/250
# 2/2 - 0s - loss: 0.0146 - root_mean_squared_error: 0.0275 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0064 - 26ms/epoch - 13ms/step
# Epoch 229/250
# 2/2 - 0s - loss: 0.0142 - root_mean_squared_error: 0.0287 - val_loss: 0.0180 - val_root_mean_squared_error: 0.0183 - 27ms/epoch - 13ms/step
# Epoch 230/250
# 2/2 - 0s - loss: 0.0214 - root_mean_squared_error: 0.0351 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0044 - 27ms/epoch - 13ms/step
# Epoch 231/250
# 2/2 - 0s - loss: 0.0168 - root_mean_squared_error: 0.0296 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0111 - 29ms/epoch - 14ms/step
# Epoch 232/250
# 2/2 - 0s - loss: 0.0172 - root_mean_squared_error: 0.0307 - val_loss: 0.0150 - val_root_mean_squared_error: 0.0154 - 25ms/epoch - 13ms/step
# Epoch 233/250
# 2/2 - 0s - loss: 0.0234 - root_mean_squared_error: 0.0360 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0057 - 26ms/epoch - 13ms/step
# Epoch 234/250
# 2/2 - 0s - loss: 0.0138 - root_mean_squared_error: 0.0274 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0122 - 26ms/epoch - 13ms/step
# Epoch 235/250
# 2/2 - 0s - loss: 0.0169 - root_mean_squared_error: 0.0287 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0119 - 25ms/epoch - 13ms/step
# Epoch 236/250
# 2/2 - 0s - loss: 0.0174 - root_mean_squared_error: 0.0356 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0044 - 26ms/epoch - 13ms/step
# Epoch 237/250
# 2/2 - 0s - loss: 0.0142 - root_mean_squared_error: 0.0254 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0052 - 26ms/epoch - 13ms/step
# Epoch 238/250
# 2/2 - 0s - loss: 0.0153 - root_mean_squared_error: 0.0296 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0123 - 26ms/epoch - 13ms/step
# Epoch 239/250
# 2/2 - 0s - loss: 0.0175 - root_mean_squared_error: 0.0314 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0060 - 26ms/epoch - 13ms/step
# Epoch 240/250
# 2/2 - 0s - loss: 0.0151 - root_mean_squared_error: 0.0287 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0042 - 26ms/epoch - 13ms/step
# Epoch 241/250
# 2/2 - 0s - loss: 0.0130 - root_mean_squared_error: 0.0297 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0050 - 26ms/epoch - 13ms/step
# Epoch 242/250
# 2/2 - 0s - loss: 0.0124 - root_mean_squared_error: 0.0276 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0084 - 26ms/epoch - 13ms/step
# Epoch 243/250
# 2/2 - 0s - loss: 0.0140 - root_mean_squared_error: 0.0268 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0091 - 26ms/epoch - 13ms/step
# Epoch 244/250
# 2/2 - 0s - loss: 0.0176 - root_mean_squared_error: 0.0336 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0054 - 26ms/epoch - 13ms/step
# Epoch 245/250
# 2/2 - 0s - loss: 0.0146 - root_mean_squared_error: 0.0288 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0088 - 61ms/epoch - 30ms/step
# Epoch 246/250
# 2/2 - 0s - loss: 0.0149 - root_mean_squared_error: 0.0299 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0089 - 27ms/epoch - 14ms/step
# Epoch 247/250
# 2/2 - 0s - loss: 0.0154 - root_mean_squared_error: 0.0291 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0073 - 27ms/epoch - 13ms/step
# Epoch 248/250
# 2/2 - 0s - loss: 0.0154 - root_mean_squared_error: 0.0304 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0033 - 26ms/epoch - 13ms/step
# Epoch 249/250
# 2/2 - 0s - loss: 0.0126 - root_mean_squared_error: 0.0261 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0064 - 32ms/epoch - 16ms/step
# Epoch 250/250
# 2/2 - 0s - loss: 0.0148 - root_mean_squared_error: 0.0258 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0073 - 61ms/epoch - 30ms/step

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Train vs. Validation MAE Loss by Epoch')
plt.xlabel('Epochs')
plt.ylabel('MAE Loss')
plt.legend()
plt.show()

# %%
# Predict on Train and Test data
LSTM_train_pred = model.predict(LSTM_X_train).flatten()
LSTM_val_pred = model.predict(LSTM_X_val).flatten()
LSTM_test_pred = model.predict(LSTM_X_test).flatten()
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
# Convert into pred and observed dataframe for RMSE
LSTM_train_results_df = pd.DataFrame(data={'Predictions': LSTM_train_pred, 'Observed': LSTM_y_train})
LSTM_val_results_df = pd.DataFrame(data={'Predictions': LSTM_val_pred, 'Observed': LSTM_y_val})
LSTM_test_results_df = pd.DataFrame(data={'Predictions': LSTM_test_pred, 'Observed': LSTM_y_test})

# %%
# Calculate RMSE on Train and test data:
LSTM_rmse_train = np.sqrt(mean_squared_error(LSTM_train_results_df['Predictions'], LSTM_train_results_df['Observed']))
LSTM_rmse_val = np.sqrt(mean_squared_error(LSTM_val_results_df['Predictions'], LSTM_val_results_df['Observed']))
LSTM_rmse_test = np.sqrt(mean_squared_error(LSTM_test_results_df['Predictions'], LSTM_test_results_df['Observed']))

print('Train RMSE: %.3f' % LSTM_rmse_train)
print('Val RMSE: %.3f' % LSTM_rmse_val)
print('Test RMSE: %.3f' % LSTM_rmse_test)
# Out:
# Train RMSE: 0.026
# Val RMSE: 0.007
# Test RMSE: 0.006

# %%
LSTM_trial_pred = model.predict(LSTM_X[120:]).flatten()
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
# LSTM_results = pd.concat([LSTM_train_results_df, LSTM_val_results_df, LSTM_test_results_df]).set_index(monthly_pca_bitcoin_df.index[5:])
LSTM_results = results_original_scale(source_array=LSTM_X_prime,
                                      predictions=LSTM_trial_pred,
                                      scaler=scaler,
                                      index=X_prime.index,
                                      window=Window)

# %%
LSTM_trial_pred = model.predict(LSTM_X).flatten()
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
LSTM_trial_results = pd.DataFrame(data={'Observed': LSTM_y, 'Predictions': LSTM_trial_pred})

# %%
LSTM_trial_results.plot()
# Out:
# <Axes: >

# %%
plt.plot(LSTM_results['Observed'], label='Observed')
plt.plot(LSTM_results['Predictions'], label='Predicted')
plt.title('Predicted Values vs. Observed Values')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
LSTM_train_results_df.plot()
LSTM_val_results_df.plot()
LSTM_test_results_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# Much more Accurate! Now let's see about if there are any hyper-parameters we can adjust to make this model even better.

# %%
def LSTM_model_gen(X_y_list, num_layers, num_nodes, dropout, loss, optimizer):
    '''
    Generates a list of models to be iterated
    '''
    params = {'num_layers': None, 'num_nodes': None, 'dropout': None, 'loss': None, 'optimizer': None, 'Data': None}
    models_dict = {}
    # Generate list of models and dictionary of parameters
    for func in loss:
        for optim in optimizer:
            for i in num_layers:
                for j in num_nodes:
                    for drop in dropout:
                        for tup in X_y_list:
                            model = Sequential()
                            if i == 1:
                                model.add(LSTM(j, input_shape=(tup[0].shape[1], tup[0].shape[2])))
                                model.add(Dropout(drop))
                                model.add(Dense(1))
                                model.compile(loss=func, optimizer=optim)
                                params_list = [i, j, drop, func, optim, tup]
                                keys_list = params.keys()
                                params = dict(zip(keys_list, params_list))
                                models_dict[f'Model{len(models_dict) + 1}'] = (model, params)
                            else:
                                model.add(LSTM(j, input_shape=(tup[0].shape[1], tup[0].shape[2]), return_sequences=True))
                                for _ in range(i-1):
                                    model.add(LSTM(j, return_sequences=True))
                                model.add(Dropout(drop))
                                model.add(Dense(1))
                                model.compile(loss=func, optimizer=optim)
                                params_list = [i, j, drop, func, optim, tup]
                                keys_list = params.keys()
                                params = dict(zip(keys_list, params_list))
                                models_dict[f'Model {len(models_dict) + 1}'] = (model, params)

    return models_dict

def viz_model(history, key, models_dict, results):
    _, (ax1,ax2) = plt.subplots(ncols=2,figsize=(25, 7))
    # Plot training and Validation scores by Epoch
    ax1.plot(history.history['loss'], label='train')
    ax1.plot(history.history['val_loss'], label='test')
    ax1.set_title(f'Train vs. Validation {list(models_dict[key][1].keys())[3].upper()} Loss by Epoch')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel(f'{list(models_dict[key][1].keys())[3].upper()} Loss')
    ax1.legend()

    # Rough Plot of Predicted against True Values Stationary Transformation
    ax2.plot(results['Observed'], label='observed', color='b')
    ax2.plot(results['Predictions'], label='predicted', color='r')
    ax2.set_title('Predicted Values vs. Observed Values')
    ax2.set_xlabel('Date')
    ax2.set_ylabel('Values in $s')
    ax2.legend()

    # Plot of original Value data against Predicted (Transformed) Data
    # ax3.plot(monthly_pca_bitcoin_df.index, monthly_pca_bitcoin_df['Market Price'], label='Observed', color='b')
    # ax3.plot(LSTM_X_prime.index, np.exp(np.cumsum(inv_test_pred)) +  monthly_pca_bitcoin_df['Market Price'].iloc[-len(inv_test_pred)], color='r', label='Predicted')
    # ax3.set_title('Predicted Values vs. Observed Values Original Scale')
    # ax3.set_xlabel('Date')
    # ax3.set_ylabel('Values in $s')
    # ax3.legend()
                
    plt.suptitle(f'{key} Performance Visualization')
    plt.show()

def model_metrics(key, models_dict, rmse_train, rmse_val, rmse_test):
    # Print Model Params and RMSE metrics before Plotting
    print('#######################')
    print(f'{key} Parameters:')
    for key2 in models_dict[key][1].keys():
        print(f'\t{key2}: {models_dict[key][1][key2]}')
    print('#######################')
    print('Train RMSE: %.3f' % rmse_train)
    print('Val RMSE: %.3f' % rmse_val)
    print('Test RMSE: %.3f' % rmse_test)
    print('#######################\n')
                        
def windowed_X_y_gen(df, window):
    '''
    takes a dataset and and a window size and returns a list of tuples containing in order:
    X_train, y_train, X_val, y_val, X_test, y_test
    to be iterated by the LSTM_tuner function
    '''
    X_y_list = []
    for size in window:
        X, y = to_X_y(df, window=size)
        X_train, y_train, X_val, y_val, X_test, y_test = train_test_val_split(X, y)
        X_y_list.append((X_train, y_train, X_val, y_val, X_test, y_test))
    return X_y_list
    
def LSTM_tuner(X_y_list, num_epochs, batch_size, num_layers, num_nodes, dropout, loss, optimizer, scaler, callback):
    '''
    Takes in previously formated X, and y np.Arrays for LSTM modeling and tunes model parameters and model layers
    in order to find the best model for the dataset.
    '''
    # Instantiate Models
    best_model = {'Model #': None, 'Model': None, 'History': None, 'Params': None, 'MAE': None, 'RMSE trainset score': None, 'RMSE testset score': None, 'Window': None}
    print("Initializing Models Dictionary....")
    models_dict = LSTM_model_gen(X_y_list=X_y_list,
                                    num_layers=num_layers,
                                    num_nodes=num_nodes,
                                    dropout=dropout,
                                    loss=loss,
                                    optimizer=optimizer)
    
    print(f"Complete:    Num Models: {len(models_dict)}")
    print("########################\n")
    print('Training Models....')
    # Train Model
    for i in num_epochs:
        for k in batch_size:
            for key in models_dict.keys():
                print(f'\tTraining {key}....')
                history = models_dict[key][0].fit(models_dict[key][1]['Data'][0],
                            models_dict[key][1]['Data'][1],
                            callbacks=[callback],
                            epochs=i,
                            batch_size=k,
                            validation_data=(models_dict[key][1]['Data'][2], models_dict[key][1]['Data'][3]),
                            verbose=0,
                            shuffle=False)
                
                # Predict on Train and Test data
                print(f'Evaluating {key}....')
                # train_pred = models_dict[key][0].predict(X_y_list[tup][0])
                # test_pred = models_dict[key][0].predict(X_y_list[tup][2])
                train_pred = model.predict(models_dict[key][1]['Data'][0]).flatten()
                val_pred = model.predict(models_dict[key][1]['Data'][2]).flatten()
                test_pred = model.predict(models_dict[key][1]['Data'][4]).flatten()

                # convert from 3 dimensions to 2 dimensions X_train and Predictions
                # train_pred_dim1, train_pred_dim2 = train_pred.shape[0], train_pred.shape[-1]
                # test_pred_dim1, test_pred_dim2 = test_pred.shape[0], test_pred.shape[-1]
                
                # new_X_train = X_train.reshape((X_train.shape[0], X_train.shape[2]))
                # new_X_test = X_test.reshape((X_test.shape[0], X_test.shape[2]))
                # new_train_pred = train_pred.flatten().reshape(train_pred_dim1, train_pred_dim2)
                # new_test_pred = test_pred.flatten().reshape(test_pred_dim1, test_pred_dim2)

                # Create inverted sets
                # inv_train_pred = np.concatenate((new_X_train, new_train_pred), axis=1)
                # inv_test_pred = np.concatenate((new_X_test, new_test_pred), axis=1)

                # Transform to original scale
                # inv_train_pred = scaler.inverse_transform(inv_train_pred)
                # inv_test_pred = scaler.inverse_transform(inv_test_pred)
                

                # Predicted values on training data
                # inv_train_pred = inv_train_pred[:,-1] 
    
                # Predicted values on testing data
                # inv_test_pred = inv_test_pred[:,-1] 

                # Scale back original train and test labels:
                #   Train set:
                # new_y_train = y_train.reshape((len(y_train), 1))
                # inv_y_train = np.concatenate((new_X_train, new_y_train), axis=1)
                # inv_y_train = scaler.inverse_transform(inv_y_train)
                # inv_y_train = inv_y_train[:,-1]

                #   Test set:
                # new_y_test = y_test.reshape((len(y_test), 1))
                # inv_y_test = np.concatenate((new_X_test, new_y_test), axis=1)
                # inv_y_test = scaler.inverse_transform(inv_y_test)
                # inv_y_test = inv_y_test[:,-1]

                # Calculate RMSE on Train and test data:
                train_results_df = pd.DataFrame(data={'Predictions': train_pred, 'Observed': models_dict[key][1]['Data'][1]})
                val_results_df = pd.DataFrame(data={'Predictions': val_pred, 'Observed': models_dict[key][1]['Data'][3]})
                test_results_df = pd.DataFrame(data={'Predictions': test_pred, 'Observed': models_dict[key][1]['Data'][5]})
                
                final_pred = model.predict(LSTM_X[120:]).flatten()
                
                rmse_train = np.sqrt(mean_squared_error(train_results_df['Predictions'], train_results_df['Observed']))
                rmse_val = np.sqrt(mean_squared_error(val_results_df['Predictions'], val_results_df['Observed']))
                rmse_test = np.sqrt(mean_squared_error(test_results_df['Predictions'], test_results_df['Observed']))
                
                results = results_original_scale(source_array=LSTM_X_prime,
                                      predictions=final_pred,
                                      scaler=scaler,
                                      index=X_prime.index,
                                      window=models_dict[key][1]['Data'][0].shape[1])

                # Reshape data for plotting
                # inv_y_test = inv_y_test.reshape(-1,1)
                
                params = [key, models_dict[key][0], history, models_dict[key][1], min(history.history['val_loss']), rmse_train, rmse_test, models_dict[key][1]['Data'][0].shape[1]]
                if best_model['Model'] == None:
                    keys_list = best_model.keys()
                    best_model = dict(zip(keys_list, params))
                    print('Best Model updated')
                    print(f'{key}:  {best_model}')
                    print('Graphing...')
                    viz_model(history, key, models_dict, results)
                    model_metrics(key, models_dict, rmse_train, rmse_val, rmse_test)
                elif min(history.history['val_loss']) < best_model['MAE']:
                    keys_list = best_model.keys()
                    best_model = dict(zip(keys_list, params))
                    print('Best Model updated')
                    print(f'{key}:  {best_model}')
                    print('Graphing...')
                    viz_model(history, key, models_dict, results)
                    model_metrics(key, models_dict, rmse_train, rmse_val, rmse_test)

    print('...finished\n')
    print('Best Model:')
    print('###################')
    for keys in best_model.keys():
        print(f'\t{keys}:   {best_model[keys]}')
    print('###################')
    return best_model

# %%
num_epochs = np.arange(25, 125, 25)
batch_size = np.arange(10, (len(LSTM_X_prime) + 10), 10)
num_layers = [1, 2, 3]
num_nodes = np.arange(100, 525, 25)
dropout = np.arange(0.1, 0.35, 0.05)
loss = ['mae']
optimizer = ['adam']
callback = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True, mode='min')
Window = np.arange(3, 9, 1)

###DEBUG SET###
# num_epochs = [150, 200, 250]
# batch_size = [50, 100, 150]
# num_layers = [1, 2, 3]
# num_nodes = [100, 250, 500]
# dropout = [0.15, 0.2, 0.25]
# loss = ['mae']
# optimizer = ['adam']
# callback = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True, mode='min')

# Divide Data into Train and Test data
# LSTM_X_prime = scaler.fit_transform(X_prime)
# LSTM_X_train_size = int(len(LSTM_X_prime) * 0.80)
# LSTM_X_test_size = len(LSTM_X_prime) - LSTM_X_train_size

# LSTM_train, LSTM_test = LSTM_X_prime[0:LSTM_X_train_size, :], LSTM_X_prime[LSTM_X_train_size:len(LSTM_X_prime),:]
# LSTM_X_train, LSTM_y_train = LSTM_train[:, :-1], LSTM_train[:, -1]
# LSTM_X_test, LSTM_y_test = LSTM_test[:, :-1], LSTM_test[:, -1]

# Convert X data into correct dimension for LSTM Model
# LSTM_X_train = LSTM_X_train.reshape((LSTM_X_train.shape[0], 1, LSTM_X_train.shape[1]))
# LSTM_X_test = LSTM_X_test.reshape((LSTM_X_test.shape[0], 1, LSTM_X_test.shape[1]))
X_y_list = windowed_X_y_gen(LSTM_X_prime, window=Window)

LSTM_best_model = LSTM_tuner(X_y_list=X_y_list,
                            #  X_train=LSTM_X_train,
                            #  y_train=LSTM_y_train,
                            #  X_test=LSTM_X_test,
                            #  y_test=LSTM_y_test,
                             num_epochs=num_epochs,
                             batch_size=batch_size,
                             num_layers=num_layers,
                             num_nodes=num_nodes,
                             dropout=dropout,
                             loss=loss,
                             optimizer=optimizer,
                             scaler=scaler,
                             callback=callback)
# Out:
# Initializing Models Dictionary....
# Complete:    Num Models: 1530
# ########################
#
# Training Models....
# 	Training Model1....
# Evaluating Model1....
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 2ms/step
# Best Model updated
# Model1:  {'Model #': 'Model1', 'Model': <keras.engine.sequential.Sequential object at 0x0000023AE01FB520>, 'History': <keras.callbacks.History object at 0x0000023CD98A9210>, 'Params': {'num_layers': 1, 'num_nodes': 100, 'dropout': 0.1, 'loss': 'mae', 'optimizer': 'adam', 'Data': (array([[[0.        , 0.28694383, 0.3419535 , ..., 0.5968853 ,
#          0.35837074, 0.70168439],
#         [0.00183249, 0.28663332, 0.34304022, ..., 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, ..., 0.6007618 ,
#          0.34483329, 0.70491325]],
#
#        [[0.00183249, 0.28663332, 0.34304022, ..., 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, ..., 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , ..., 0.59969499,
#          0.34634517, 0.70537568]],
#
#        [[0.00225596, 0.29233054, 0.34140905, ..., 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , ..., 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, ..., 0.59964867,
#          0.34241582, 0.70778408]],
#
#        ...,
#
#        [[0.47304842, 0.64917202, 0.14053419, ..., 0.73140103,
#          0.44621688, 0.70781041],
#         [0.51225225, 0.75565395, 0.0911731 , ..., 0.70928545,
#          0.48304797, 0.74789429],
#         [0.50966966, 0.7309028 , 0.34995516, ..., 0.69729285,
#          0.28171766, 0.65011905]],
#
#        [[0.51225225, 0.75565395, 0.0911731 , ..., 0.70928545,
#          0.48304797, 0.74789429],
#         [0.50966966, 0.7309028 , 0.34995516, ..., 0.69729285,
#          0.28171766, 0.65011905],
#         [0.5163276 , 0.64465023, 0.1897007 , ..., 0.73146276,
#          0.5232984 , 0.75102546]],
#
#        [[0.50966966, 0.7309028 , 0.34995516, ..., 0.69729285,
#          0.28171766, 0.65011905],
#         [0.5163276 , 0.64465023, 0.1897007 , ..., 0.73146276,
#          0.5232984 , 0.75102546],
#         [0.64574787, 0.62774664, 0.44481836, ..., 0.63208279,
#          0.594603  , 0.7887688 ]]]), array([3.41705216e-06, 1.27493375e-05, 1.28929111e-05, 1.05957332e-05,
#        5.78314543e-05, 1.33939830e-04, 2.43184998e-04, 2.00974354e-04,
#        1.20419503e-04, 7.52038623e-05, 4.72070064e-05, 4.41919603e-05,
#        6.32872518e-05, 8.00566507e-05, 7.06095065e-05, 6.98772810e-05,
#        7.08966537e-05, 7.47731415e-05, 9.52180250e-05, 1.31484722e-04,
#        1.48713556e-04, 1.78304079e-04, 1.61046530e-04, 1.81273182e-04,
#        1.93939246e-04, 3.04921655e-04, 4.99865917e-04, 1.32716583e-03,
#        2.07432295e-03, 1.85407384e-03, 1.30560107e-03, 1.49500339e-03,
#        1.79148292e-03, 1.82263840e-03, 2.91710010e-03, 1.39257510e-02,
#        1.07226235e-02, 1.14849995e-02, 8.20434225e-03, 6.88360851e-03,
#        6.60363995e-03, 8.91933888e-03, 8.61338349e-03, 8.64138035e-03,
#        6.92782919e-03, 5.53057071e-03, 4.95670695e-03, 5.39159145e-03,
#        4.53172904e-03, 3.16806679e-03, 3.61874439e-03, 3.48364161e-03,
#        3.35054886e-03, 3.19218716e-03, 3.70115564e-03, 4.14049092e-03,
#        3.31479903e-03, 3.43023222e-03, 4.46310085e-03, 5.34765792e-03,
#        6.14736299e-03, 5.40982530e-03, 6.19991093e-03, 5.98526837e-03,
#        6.41929142e-03, 7.62502269e-03, 9.63864271e-03, 9.39858762e-03,
#        8.25200869e-03, 8.74834269e-03, 1.00779780e-02, 1.06621791e-02,
#        1.37551856e-02, 1.38497446e-02, 1.70494148e-02, 1.48552466e-02,
#        1.91374734e-02, 3.28190904e-02, 3.55715044e-02, 4.11535075e-02,
#        6.57920085e-02, 5.97870418e-02, 9.17232019e-02, 1.45688603e-01,
#        2.03379399e-01, 1.44757500e-01, 1.48887323e-01, 9.95743071e-02,
#        1.32942109e-01, 1.06052923e-01, 8.93489938e-02, 1.13663485e-01,
#        1.00241439e-01, 9.46591360e-02, 9.04736060e-02, 6.14309598e-02,
#        5.44357056e-02, 4.98191561e-02, 5.50341807e-02, 5.90716145e-02,
#        7.55281664e-02, 1.18769813e-01, 1.70713600e-01, 1.37673721e-01,
#        1.37513780e-01, 1.15672643e-01, 1.31578877e-01, 1.11375915e-01,
#        1.03653521e-01, 1.36428076e-01, 1.25085473e-01, 9.19621773e-02,
#        1.26022722e-01, 1.39238243e-01, 1.31876505e-01, 1.59580184e-01,
#        1.68091946e-01, 1.55644400e-01, 1.94752706e-01, 2.61182497e-01,
#        4.14303620e-01, 4.92716496e-01]), array([[[0.        , 0.28694383, 0.3419535 , 0.45626163, 0.76586114,
#          0.19880133, 0.63617026, 0.69945214, 0.46201536, 0.5968853 ,
#          0.35837074, 0.70168439],
#         [0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325]],
#
#        [[0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568]],
#
#        [[0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408]],
#
#        [[0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258]],
#
#        [[0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461]],
#
#        [[0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663]],
#
#        [[0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ]],
#
#        [[0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937]],
#
#        [[0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451]],
#
#        [[0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173]],
#
#        [[0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342]],
#
#        [[0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283]],
#
#        [[0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152]],
#
#        [[0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404]],
#
#        [[0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241]],
#
#        [[0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749]],
#
#        [[0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749],
#         [0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452]],
#
#        [[0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749],
#         [0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452],
#         [0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ]],
#
#        [[0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452],
#         [0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ],
#         [0.04718018, 0.5364272 , 0.31744998, 0.66653192, 0.55985271,
#          0.42145452, 0.45052698, 0.61302956, 0.63807106, 0.5882593 ,
#          0.2868606 , 0.77474486]],
#
#        [[0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ],
#         [0.04718018, 0.5364272 , 0.31744998, 0.66653192, 0.55985271,
#          0.42145452, 0.45052698, 0.61302956, 0.63807106, 0.5882593 ,
#          0.2868606 , 0.77474486],
#         [0.05300479, 0.47341977, 0.31024578, 0.51304757, 0.72046223,
#          0.23987674, 0.57982593, 0.70202178, 0.84037544, 0.58180959,
#          0.36447396, 0.74745762]],
#
#        [[0.04718018, 0.5364272 , 0.31744998, 0.66653192, 0.55985271,
#          0.42145452, 0.45052698, 0.61302956, 0.63807106, 0.5882593 ,
#          0.2868606 , 0.77474486],
#         [0.05300479, 0.47341977, 0.31024578, 0.51304757, 0.72046223,
#          0.23987674, 0.57982593, 0.70202178, 0.84037544, 0.58180959,
#          0.36447396, 0.74745762],
#         [0.07906759, 0.59790105, 0.29964439, 0.59448478, 0.65006901,
#          0.31783063, 0.50740103, 0.70840772, 1.        , 0.56907734,
#          0.38536018, 0.77317592]],
#
#        [[0.05300479, 0.47341977, 0.31024578, 0.51304757, 0.72046223,
#          0.23987674, 0.57982593, 0.70202178, 0.84037544, 0.58180959,
#          0.36447396, 0.74745762],
#         [0.07906759, 0.59790105, 0.29964439, 0.59448478, 0.65006901,
#          0.31783063, 0.50740103, 0.70840772, 1.        , 0.56907734,
#          0.38536018, 0.77317592],
#         [0.07514171, 0.62928975, 0.32116201, 0.87590473, 0.58830807,
#          0.45331495, 0.4669472 , 1.        , 0.64385037, 0.50946683,
#          0.30005505, 0.82764868]],
#
#        [[0.07906759, 0.59790105, 0.29964439, 0.59448478, 0.65006901,
#          0.31783063, 0.50740103, 0.70840772, 1.        , 0.56907734,
#          0.38536018, 0.77317592],
#         [0.07514171, 0.62928975, 0.32116201, 0.87590473, 0.58830807,
#          0.45331495, 0.4669472 , 1.        , 0.64385037, 0.50946683,
#          0.30005505, 0.82764868],
#         [0.05803301, 0.50589764, 0.30641235, 0.54431683, 0.6795389 ,
#          0.28639049, 0.56334758, 0.64763505, 0.80639994, 0.59289839,
#          0.34149733, 0.75823451]],
#
#        [[0.07514171, 0.62928975, 0.32116201, 0.87590473, 0.58830807,
#          0.45331495, 0.4669472 , 1.        , 0.64385037, 0.50946683,
#          0.30005505, 0.82764868],
#         [0.05803301, 0.50589764, 0.30641235, 0.54431683, 0.6795389 ,
#          0.28639049, 0.56334758, 0.64763505, 0.80639994, 0.59289839,
#          0.34149733, 0.75823451],
#         [0.06502555, 0.5534875 , 0.3090475 , 0.60043905, 0.66170942,
#          0.31891519, 0.57071648, 0.70028172, 0.84998118, 0.57544736,
#          0.34231975, 0.76983261]]]), array([3.41705216e-06, 1.27493375e-05, 1.28929111e-05, 1.05957332e-05,
#        5.78314543e-05, 1.33939830e-04, 2.43184998e-04, 2.00974354e-04,
#        1.20419503e-04, 7.52038623e-05, 4.72070064e-05, 4.41919603e-05,
#        6.32872518e-05, 8.00566507e-05, 7.06095065e-05, 6.98772810e-05,
#        7.08966537e-05, 7.47731415e-05, 9.52180250e-05, 1.31484722e-04,
#        1.48713556e-04, 1.78304079e-04, 1.61046530e-04, 1.81273182e-04]), array([[[0.        , 0.28694383, 0.3419535 , 0.45626163, 0.76586114,
#          0.19880133, 0.63617026, 0.69945214, 0.46201536, 0.5968853 ,
#          0.35837074, 0.70168439],
#         [0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325]],
#
#        [[0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568]],
#
#        [[0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408]],
#
#        [[0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258]],
#
#        [[0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461]],
#
#        [[0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663]],
#
#        [[0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ]],
#
#        [[0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937]],
#
#        [[0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451]],
#
#        [[0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173]],
#
#        [[0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342]],
#
#        [[0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283]],
#
#        [[0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152]],
#
#        [[0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404]],
#
#        [[0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241]],
#
#        [[0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749]]]), array([3.41705216e-06, 1.27493375e-05, 1.28929111e-05, 1.05957332e-05,
#        5.78314543e-05, 1.33939830e-04, 2.43184998e-04, 2.00974354e-04,
#        1.20419503e-04, 7.52038623e-05, 4.72070064e-05, 4.41919603e-05,
#        6.32872518e-05, 8.00566507e-05, 7.06095065e-05, 6.98772810e-05]))}, 'MAE': 0.0061805713921785355, 'RMSE trainset score': 0.04251878697084829, 'RMSE testset score': 0.016738785832474793, 'Window': 3}
# Graphing...
# #######################
# Model1 Parameters:
# 	num_layers: 1
# 	num_nodes: 100
# 	dropout: 0.1
# 	loss: mae
# 	optimizer: adam
# 	Data: (array([[[0.        , 0.28694383, 0.3419535 , ..., 0.5968853 ,
#          0.35837074, 0.70168439],
#         [0.00183249, 0.28663332, 0.34304022, ..., 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, ..., 0.6007618 ,
#          0.34483329, 0.70491325]],
#
#        [[0.00183249, 0.28663332, 0.34304022, ..., 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, ..., 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , ..., 0.59969499,
#          0.34634517, 0.70537568]],
#
#        [[0.00225596, 0.29233054, 0.34140905, ..., 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , ..., 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, ..., 0.59964867,
#          0.34241582, 0.70778408]],
#
#        ...,
#
#        [[0.47304842, 0.64917202, 0.14053419, ..., 0.73140103,
#          0.44621688, 0.70781041],
#         [0.51225225, 0.75565395, 0.0911731 , ..., 0.70928545,
#          0.48304797, 0.74789429],
#         [0.50966966, 0.7309028 , 0.34995516, ..., 0.69729285,
#          0.28171766, 0.65011905]],
#
#        [[0.51225225, 0.75565395, 0.0911731 , ..., 0.70928545,
#          0.48304797, 0.74789429],
#         [0.50966966, 0.7309028 , 0.34995516, ..., 0.69729285,
#          0.28171766, 0.65011905],
#         [0.5163276 , 0.64465023, 0.1897007 , ..., 0.73146276,
#          0.5232984 , 0.75102546]],
#
#        [[0.50966966, 0.7309028 , 0.34995516, ..., 0.69729285,
#          0.28171766, 0.65011905],
#         [0.5163276 , 0.64465023, 0.1897007 , ..., 0.73146276,
#          0.5232984 , 0.75102546],
#         [0.64574787, 0.62774664, 0.44481836, ..., 0.63208279,
#          0.594603  , 0.7887688 ]]]), array([3.41705216e-06, 1.27493375e-05, 1.28929111e-05, 1.05957332e-05,
#        5.78314543e-05, 1.33939830e-04, 2.43184998e-04, 2.00974354e-04,
#        1.20419503e-04, 7.52038623e-05, 4.72070064e-05, 4.41919603e-05,
#        6.32872518e-05, 8.00566507e-05, 7.06095065e-05, 6.98772810e-05,
#        7.08966537e-05, 7.47731415e-05, 9.52180250e-05, 1.31484722e-04,
#        1.48713556e-04, 1.78304079e-04, 1.61046530e-04, 1.81273182e-04,
#        1.93939246e-04, 3.04921655e-04, 4.99865917e-04, 1.32716583e-03,
#        2.07432295e-03, 1.85407384e-03, 1.30560107e-03, 1.49500339e-03,
#        1.79148292e-03, 1.82263840e-03, 2.91710010e-03, 1.39257510e-02,
#        1.07226235e-02, 1.14849995e-02, 8.20434225e-03, 6.88360851e-03,
#        6.60363995e-03, 8.91933888e-03, 8.61338349e-03, 8.64138035e-03,
#        6.92782919e-03, 5.53057071e-03, 4.95670695e-03, 5.39159145e-03,
#        4.53172904e-03, 3.16806679e-03, 3.61874439e-03, 3.48364161e-03,
#        3.35054886e-03, 3.19218716e-03, 3.70115564e-03, 4.14049092e-03,
#        3.31479903e-03, 3.43023222e-03, 4.46310085e-03, 5.34765792e-03,
#        6.14736299e-03, 5.40982530e-03, 6.19991093e-03, 5.98526837e-03,
#        6.41929142e-03, 7.62502269e-03, 9.63864271e-03, 9.39858762e-03,
#        8.25200869e-03, 8.74834269e-03, 1.00779780e-02, 1.06621791e-02,
#        1.37551856e-02, 1.38497446e-02, 1.70494148e-02, 1.48552466e-02,
#        1.91374734e-02, 3.28190904e-02, 3.55715044e-02, 4.11535075e-02,
#        6.57920085e-02, 5.97870418e-02, 9.17232019e-02, 1.45688603e-01,
#        2.03379399e-01, 1.44757500e-01, 1.48887323e-01, 9.95743071e-02,
#        1.32942109e-01, 1.06052923e-01, 8.93489938e-02, 1.13663485e-01,
#        1.00241439e-01, 9.46591360e-02, 9.04736060e-02, 6.14309598e-02,
#        5.44357056e-02, 4.98191561e-02, 5.50341807e-02, 5.90716145e-02,
#        7.55281664e-02, 1.18769813e-01, 1.70713600e-01, 1.37673721e-01,
#        1.37513780e-01, 1.15672643e-01, 1.31578877e-01, 1.11375915e-01,
#        1.03653521e-01, 1.36428076e-01, 1.25085473e-01, 9.19621773e-02,
#        1.26022722e-01, 1.39238243e-01, 1.31876505e-01, 1.59580184e-01,
#        1.68091946e-01, 1.55644400e-01, 1.94752706e-01, 2.61182497e-01,
#        4.14303620e-01, 4.92716496e-01]), array([[[0.        , 0.28694383, 0.3419535 , 0.45626163, 0.76586114,
#          0.19880133, 0.63617026, 0.69945214, 0.46201536, 0.5968853 ,
#          0.35837074, 0.70168439],
#         [0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325]],
#
#        [[0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568]],
#
#        [[0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408]],
#
#        [[0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258]],
#
#        [[0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461]],
#
#        [[0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663]],
#
#        [[0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ]],
#
#        [[0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937]],
#
#        [[0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451]],
#
#        [[0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173]],
#
#        [[0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342]],
#
#        [[0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283]],
#
#        [[0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152]],
#
#        [[0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404]],
#
#        [[0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241]],
#
#        [[0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749]],
#
#        [[0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749],
#         [0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452]],
#
#        [[0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749],
#         [0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452],
#         [0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ]],
#
#        [[0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452],
#         [0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ],
#         [0.04718018, 0.5364272 , 0.31744998, 0.66653192, 0.55985271,
#          0.42145452, 0.45052698, 0.61302956, 0.63807106, 0.5882593 ,
#          0.2868606 , 0.77474486]],
#
#        [[0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ],
#         [0.04718018, 0.5364272 , 0.31744998, 0.66653192, 0.55985271,
#          0.42145452, 0.45052698, 0.61302956, 0.63807106, 0.5882593 ,
#          0.2868606 , 0.77474486],
#         [0.05300479, 0.47341977, 0.31024578, 0.51304757, 0.72046223,
#          0.23987674, 0.57982593, 0.70202178, 0.84037544, 0.58180959,
#          0.36447396, 0.74745762]],
#
#        [[0.04718018, 0.5364272 , 0.31744998, 0.66653192, 0.55985271,
#          0.42145452, 0.45052698, 0.61302956, 0.63807106, 0.5882593 ,
#          0.2868606 , 0.77474486],
#         [0.05300479, 0.47341977, 0.31024578, 0.51304757, 0.72046223,
#          0.23987674, 0.57982593, 0.70202178, 0.84037544, 0.58180959,
#          0.36447396, 0.74745762],
#         [0.07906759, 0.59790105, 0.29964439, 0.59448478, 0.65006901,
#          0.31783063, 0.50740103, 0.70840772, 1.        , 0.56907734,
#          0.38536018, 0.77317592]],
#
#        [[0.05300479, 0.47341977, 0.31024578, 0.51304757, 0.72046223,
#          0.23987674, 0.57982593, 0.70202178, 0.84037544, 0.58180959,
#          0.36447396, 0.74745762],
#         [0.07906759, 0.59790105, 0.29964439, 0.59448478, 0.65006901,
#          0.31783063, 0.50740103, 0.70840772, 1.        , 0.56907734,
#          0.38536018, 0.77317592],
#         [0.07514171, 0.62928975, 0.32116201, 0.87590473, 0.58830807,
#          0.45331495, 0.4669472 , 1.        , 0.64385037, 0.50946683,
#          0.30005505, 0.82764868]],
#
#        [[0.07906759, 0.59790105, 0.29964439, 0.59448478, 0.65006901,
#          0.31783063, 0.50740103, 0.70840772, 1.        , 0.56907734,
#          0.38536018, 0.77317592],
#         [0.07514171, 0.62928975, 0.32116201, 0.87590473, 0.58830807,
#          0.45331495, 0.4669472 , 1.        , 0.64385037, 0.50946683,
#          0.30005505, 0.82764868],
#         [0.05803301, 0.50589764, 0.30641235, 0.54431683, 0.6795389 ,
#          0.28639049, 0.56334758, 0.64763505, 0.80639994, 0.59289839,
#          0.34149733, 0.75823451]],
#
#        [[0.07514171, 0.62928975, 0.32116201, 0.87590473, 0.58830807,
#          0.45331495, 0.4669472 , 1.        , 0.64385037, 0.50946683,
#          0.30005505, 0.82764868],
#         [0.05803301, 0.50589764, 0.30641235, 0.54431683, 0.6795389 ,
#          0.28639049, 0.56334758, 0.64763505, 0.80639994, 0.59289839,
#          0.34149733, 0.75823451],
#         [0.06502555, 0.5534875 , 0.3090475 , 0.60043905, 0.66170942,
#          0.31891519, 0.57071648, 0.70028172, 0.84998118, 0.57544736,
#          0.34231975, 0.76983261]]]), array([3.41705216e-06, 1.27493375e-05, 1.28929111e-05, 1.05957332e-05,
#        5.78314543e-05, 1.33939830e-04, 2.43184998e-04, 2.00974354e-04,
#        1.20419503e-04, 7.52038623e-05, 4.72070064e-05, 4.41919603e-05,
#        6.32872518e-05, 8.00566507e-05, 7.06095065e-05, 6.98772810e-05,
#        7.08966537e-05, 7.47731415e-05, 9.52180250e-05, 1.31484722e-04,
#        1.48713556e-04, 1.78304079e-04, 1.61046530e-04, 1.81273182e-04]), array([[[0.        , 0.28694383, 0.3419535 , 0.45626163, 0.76586114,
#          0.19880133, 0.63617026, 0.69945214, 0.46201536, 0.5968853 ,
#          0.35837074, 0.70168439],
#         [0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325]],
#
#        [[0.00183249, 0.28663332, 0.34304022, 0.45858477, 0.76897757,
#          0.19544804, 0.63703918, 0.69819365, 0.46443362, 0.59977771,
#          0.34918175, 0.70209813],
#         [0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568]],
#
#        [[0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408]],
#
#        [[0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258]],
#
#        [[0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461]],
#
#        [[0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663]],
#
#        [[0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ]],
#
#        [[0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937]],
#
#        [[0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451]],
#
#        [[0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
# ...
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258]],
#
#        [[0.00225596, 0.29233054, 0.34140905, 0.4632762 , 0.75985002,
#          0.2045233 , 0.62947865, 0.68814893, 0.4600333 , 0.6007618 ,
#          0.34483329, 0.70491325],
#         [0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461]],
#
#        [[0.00342585, 0.28716968, 0.3404247 , 0.45599263, 0.77434903,
#          0.18965218, 0.64047966, 0.70248815, 0.46930223, 0.59969499,
#          0.34634517, 0.70537568],
#         [0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663]],
#
#        [[0.00406285, 0.29448041, 0.33899931, 0.46301402, 0.76387357,
#          0.20072634, 0.63186557, 0.69558553, 0.46336147, 0.59964867,
#          0.34241582, 0.70778408],
#         [0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ]],
#
#        [[0.00479925, 0.32481545, 0.33873197, 0.49974307, 0.70148275,
#          0.26392194, 0.580566  , 0.62523336, 0.42718937, 0.60934514,
#          0.31395722, 0.71414258],
#         [0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937]],
#
#        [[0.00621874, 0.2972315 , 0.338907  , 0.46215809, 0.76430421,
#          0.19947326, 0.63129509, 0.69105016, 0.46526617, 0.60232343,
#          0.33323712, 0.70608461],
#         [0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451]],
#
#        [[0.00998966, 0.30719026, 0.34434501, 0.47034131, 0.75513181,
#          0.20944534, 0.62303693, 0.68559081, 0.45831801, 0.60587687,
#          0.31626942, 0.69355663],
#         [0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173]],
#
#        [[0.01367832, 0.31182903, 0.34826589, 0.46881067, 0.75780389,
#          0.20686704, 0.62473786, 0.69133705, 0.45938453, 0.60734571,
#          0.30561623, 0.6807722 ],
#         [0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342]],
#
#        [[0.01962426, 0.32486105, 0.34879145, 0.50699701, 0.75434699,
#          0.21794472, 0.61588827, 0.72533701, 0.44964971, 0.60252431,
#          0.29136657, 0.69341937],
#         [0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283]],
#
#        [[0.01759606, 0.31076595, 0.33996374, 0.4828553 , 0.76787879,
#          0.19935404, 0.62704649, 0.70644023, 0.46209088, 0.60578204,
#          0.30251695, 0.70537451],
#         [0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152]],
#
#        [[0.01479375, 0.30902517, 0.33427642, 0.47068018, 0.76658035,
#          0.19852645, 0.62858385, 0.69880528, 0.46543153, 0.60340422,
#          0.31412943, 0.71053173],
#         [0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404]],
#
#        [[0.01403711, 0.30969895, 0.33242858, 0.47243075, 0.76362165,
#          0.20110065, 0.62605139, 0.69310152, 0.46551177, 0.60395943,
#          0.31321643, 0.71596342],
#         [0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241]],
#
#        [[0.01427444, 0.32374536, 0.33110585, 0.49488426, 0.74175764,
#          0.22592489, 0.60760959, 0.6867409 , 0.45155607, 0.6023648 ,
#          0.30663068, 0.72366283],
#         [0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749]],
#
#        [[0.01433712, 0.6927333 , 0.33883167, 1.        , 0.        ,
#          1.        , 0.        , 0.        , 0.        , 0.67660571,
#          0.02237991, 0.80878152],
#         [0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749],
#         [0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452]],
#
#        [[0.03672529, 0.43578705, 0.32164408, 0.50461205, 0.70624931,
#          0.24810783, 0.57065039, 0.63315079, 0.7852076 , 0.59965763,
#          0.35029314, 0.74416404],
#         [0.03625624, 0.42295487, 0.32177806, 0.49300191, 0.72627356,
#          0.22956814, 0.58799271, 0.66437433, 0.76609163, 0.59493969,
#          0.35321788, 0.73665241],
#         [0.03009621, 0.39632095, 0.32355736, 0.49749155, 0.71818622,
#          0.24046994, 0.58333821, 0.64819482, 0.65225444, 0.60232539,
#          0.32610522, 0.73358749],
#         [0.03207894, 0.40035808, 0.32150635, 0.49900632, 0.72690452,
#          0.23230985, 0.59149699, 0.66103889, 0.68025475, 0.59956179,
#          0.33094749, 0.74111452],
#         [0.03611911, 0.41810422, 0.3192239 , 0.51491103, 0.71958608,
#          0.24238097, 0.58091463, 0.68037359, 0.69646763, 0.59322657,
#          0.33444968, 0.7455997 ]]]), array([1.28929111e-05, 1.05957332e-05, 5.78314543e-05, 1.33939830e-04,
#        2.43184998e-04, 2.00974354e-04, 1.20419503e-04, 7.52038623e-05,
#        4.72070064e-05, 4.41919603e-05, 6.32872518e-05, 8.00566507e-05,
#        7.06095065e-05, 6.98772810e-05, 7.08966537e-05, 7.47731415e-05]))
# #######################
# Train RMSE: 0.026
# Val RMSE: 0.007
# Test RMSE: 0.006
# #######################
#
# 	Training Model 1504....
# Evaluating Model 1504....
# 4/4 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1505....
# Evaluating Model 1505....
# 4/4 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1506....
# Evaluating Model 1506....
# 4/4 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1507....
# Evaluating Model 1507....
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 6ms/step
# 	Training Model 1508....
# Evaluating Model 1508....
# 4/4 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1509....
# Evaluating Model 1509....
# 4/4 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1510....
# Evaluating Model 1510....
# 4/4 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1511....
# Evaluating Model 1511....
# 4/4 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 6ms/step
# 	Training Model 1512....
# Evaluating Model 1512....
# 4/4 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1513....
# Evaluating Model 1513....
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1514....
# Evaluating Model 1514....
# 4/4 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 8ms/step
# 	Training Model 1515....
# Evaluating Model 1515....
# 4/4 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1516....
# Evaluating Model 1516....
# 4/4 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 7ms/step
# 	Training Model 1517....

# %% [markdown]
# Our LSTM Modeling is looking excellent however leave no stone unturned.  Considering how well it works, there is concernt about bias in the modeling inspite of efforts to negate that possibility, however, deep learning models from Keras TensorFlow seems to work very well with the data and we should perhaps try a CNN model which can perform the same task more quickly due to its lightness and conveniently has windowing (kernel) packed into it which could make the process easier.  However our purpose is establish the capacity of a deep learning model against the BitCoin market value time series, which we have.  Our next class of model to test will be the SARIMAX inspite of a lack of seasonality.

# %% [markdown]
# - ##### SARIMAX  Models #####
# ***
# - Setup SARIMAX data sets for X and y inputs
# - Setup scalars and metrics
# - Create Model to test
# - Establish Hyper Parameters to tune
# - Automate model Tuning
# - Select best Model.

# %%
# SETUP VARIMAX X AND y
# We will require stationary Time Series and scaled data for this model so we will use our original X_prime as a starting point
scaler = MaxAbsScaler()
Multivar_prime = scaler.fit_transform(X_prime)
Multivar_prime = pd.DataFrame(Multivar_prime, columns=X_prime.columns, index=X_prime.index)

X_multivar = Multivar_prime[PCA_list]
y_multivar = Multivar_prime['Market Price']

# %%
X_multivar.iloc[124]
# Out:
# PCA1     0.099854
# PCA2    -0.296431
# PCA3     0.190204
# PCA4     0.064286
# PCA5     0.140986
# PCA6     0.010067
# PCA7    -0.004821
# PCA8    -0.026333
# PCA9     0.087246
# PCA10    0.130355
# PCA11    0.009312
# PCA12    0.131744
# Name: 2021-01-31 00:00:00, dtype: float64

# %%
# SARIMAX double counts the end of the train data set when predicting on Test so we'll make sure to include the last value from the train datasets
# as the first value on the test datasets.
X_train_multivar = X_multivar.loc[:'2020-11-30']
X_test_multivar = X_multivar.loc['2020-11-30':]
y_train_multivar = y_multivar.loc[:'2020-11-30']
y_test_multivar = y_multivar.loc['2020-11-30':]

# %% [markdown]
# We've scaled and separated our data into X and y Values, we shall continue to use AIC to determine best model arrangement and MAE/RMSE as metrics to determine our models' performance.

# %%
# use Auto_Arima to determine best model params.
SARIMAX_model = auto_arima(
    y=y_multivar,
    X=X_multivar,
    start_p=0,
    start_q=0,
    d=0,
    max_p=5,
    max_q=5,
    max_d=3,
    max_order=None,
    seasonal=False,
    information_criterion='bic',
    )

# %%
SARIMAX_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  165
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                  51.381
# Date:                Thu, 30 May 2024   AIC                            -72.762
# Time:                        07:27:15   BIC                            -26.173
# Sample:                    09-30-2010   HQIC                           -53.850
#                          - 05-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0507      0.023      2.176      0.030       0.005       0.096
# PCA1           0.0675      0.159      0.424      0.671      -0.244       0.379
# PCA2           0.0990      0.145      0.681      0.496      -0.186       0.384
# PCA3           0.2252      0.142      1.587      0.112      -0.053       0.503
# PCA4          -0.0450      0.143     -0.314      0.753      -0.326       0.236
# PCA5          -0.1393      0.228     -0.611      0.541      -0.586       0.308
# PCA6          -0.3269      0.297     -1.102      0.270      -0.908       0.254
# PCA7          -0.1476      0.269     -0.548      0.583      -0.675       0.380
# PCA8          -0.0270      0.226     -0.120      0.905      -0.470       0.416
# PCA9          -0.0143      0.114     -0.125      0.900      -0.237       0.209
# PCA10          0.0848      0.128      0.665      0.506      -0.165       0.335
# PCA11         -0.0218      0.122     -0.178      0.859      -0.261       0.218
# PCA12         -0.1968      0.206     -0.956      0.339      -0.600       0.207
# ma.L1          0.2341      0.067      3.513      0.000       0.104       0.365
# sigma2         0.0314      0.002     13.544      0.000       0.027       0.036
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               565.16
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.19   Skew:                             1.96
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# It's interesting to see how, like our attempt at an ARIMA model earlier in this document, it came up with the same p,d,q values for best prediction even with exogenous data to formulate predictions.  Now we'll create this model and see how it performs.

# %%
SARIMAX_model = SARIMAX(
    endog=y_train_multivar,
    exog=X_train_multivar,
    order=(0,0,1)
)

# %%
SARIMAX_results = SARIMAX_model.fit()
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           14     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.01110D-01    |proj g|=  2.92868D-01
# At iterate    5    f= -2.03663D-01    |proj g|=  3.27312D-02
#
# At iterate   10    f= -2.04850D-01    |proj g|=  5.97779D-02
#
# At iterate   15    f= -2.06016D-01    |proj g|=  1.47672D-02
#
# At iterate   20    f= -2.06324D-01    |proj g|=  2.73996D-03
#
# At iterate   25    f= -2.06368D-01    |proj g|=  5.20261D-03
#
# At iterate   30    f= -2.06380D-01    |proj g|=  4.55777D-03
#
# At iterate   35    f= -2.06384D-01    |proj g|=  2.65845D-04
#
# At iterate   40    f= -2.06384D-01    |proj g|=  3.35552D-04
#
# At iterate   45    f= -2.06384D-01    |proj g|=  1.24982D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    14     46     55      1     0     0   3.756D-05  -2.064D-01
#   F = -0.20638446533791605
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
SARIMAX_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Market Price   No. Observations:                  123
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                  25.385
# Date:                Thu, 30 May 2024   AIC                            -22.771
# Time:                        07:27:32   BIC                             16.600
# Sample:                    09-30-2010   HQIC                            -6.778
#                          - 11-30-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PCA1           0.0343      0.245      0.140      0.889      -0.446       0.514
# PCA2           0.0895      0.222      0.403      0.687      -0.346       0.525
# PCA3           0.3456      0.370      0.935      0.350      -0.379       1.070
# PCA4           0.0949      0.364      0.261      0.794      -0.618       0.808
# PCA5          -0.0108      0.461     -0.023      0.981      -0.914       0.892
# PCA6          -0.3040      0.466     -0.652      0.514      -1.217       0.610
# PCA7          -0.2265      0.325     -0.697      0.486      -0.864       0.411
# PCA8          -0.0960      0.417     -0.230      0.818      -0.914       0.722
# PCA9           0.0052      0.157      0.033      0.974      -0.303       0.314
# PCA10          0.2292      0.354      0.648      0.517      -0.464       0.922
# PCA11          0.2194      0.453      0.484      0.628      -0.669       1.108
# PCA12         -0.3102      0.570     -0.545      0.586      -1.427       0.806
# ma.L1          0.2929      0.093      3.163      0.002       0.111       0.474
# sigma2         0.0387      0.003     11.232      0.000       0.032       0.045
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.47   Jarque-Bera (JB):               380.08
# Prob(Q):                              0.49   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.16   Skew:                             2.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
SARIMAX_results.plot_diagnostics(figsize=(15,10))

# %%
predictions = pd.DataFrame(SARIMAX_results.predict(len(y_train_multivar), len(y_multivar), exog=X_test_multivar))
predictions.columns = ['Predictions']

# %%
predictions = pd.concat([y_test_multivar, predictions], axis=1).dropna()

# %%
predictions.head()
# Out:
#             Market Price  Predictions
# 2020-12-31      0.282761     0.092433
# 2021-01-31      0.106230     0.185437
# 2021-02-28      0.181622     0.039271
# 2021-03-31      0.147656     0.109208
# 2021-04-30     -0.056199     0.385152

# %%
predictions.plot()
# Out:
# <Axes: >

# %% [markdown]
# - ##### Summary #####
# ***

# %% [markdown]
# The Final graph of the stationary data from the testing datafram clearly indicates that the model is really just guessing.  A "Your guess is as good as mine" paradigm for our purposes is absolutely not sufficient.  Therefore per this analysis, the best model to follow hands down is the LSTM, specifically LSTM Model 36.  With that said however, there are likely better ways to go about doing it or better refinements we can enact on the deep learning hyper parameters.  we could consider GRUs or CNNs as potential replacements for the LSTM due to them being lighter and plausibly more accureate still.  As it stands, Neither the ARIMA, nor the SARIMAX modeling came even remotely close and the biggest concern with the LSTM is how it began to over estimate the value of Bitcoin, which could result in misguided suggestions to investors or in an investing AI, which is the grand purpose of this group of projects.
#
# Further Investigations:<br>
# I should like to investigate other currences beyond just crypto to see if they behave similarly and can therefore be generally forecast with a single currency value model.  Also, since the market has many interdynamics I will need to investigate other stocks (AMD, Intel, Apple, Microsoft, Google, Tesla, etc) which are close to cryptocurrency in the sense they provide technological services necessary for cryptocurrency minting.  Pending these analyses, next steps would include a more general investigation of stocks loosely grouped into business sectors and repeat the process of modeling their data.  Alongside these investigations will include the prediction of import indicators when making and considering investments to affect the decision making paradigm of our potential future AI.
